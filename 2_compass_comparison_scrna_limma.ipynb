# %%
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt
import scipy
from scipy import stats

# %%
root='.'
root2='/Genomics/pritykinlab/zzhao/metabolic_analysis'
filename = f'{root}/data/th_data/GSE162300_DFMO_RNA_TPMs.tsv'
reaction_meta_file = f'{root2}/Compass/compass/Resources/Recon2_export/rxn_md.csv'
reaction_output_file = f'{root}/data/compass_scrna/github_data/reactions.tsv'
scrna_metadata_file = f'{root}/data/compass_scrna/github_data/cell_metadata.csv'
out_dir = f'{root}/compass_comparison/'
hypergeom_dir = f'{out_dir}scrna/'

# %%
reaction_metadata = pd.read_csv(reaction_meta_file, index_col = 0)
reaction_penalties = pd.read_csv(reaction_output_file, sep='\t', index_col=0)
reaction_metadata
# Out:
#                                                    rxn_name_long  \
# rxn_code_nodirection
# 10FTHF5GLUtl              5-glutamyl-10FTHF transport, lysosomal
# 10FTHF5GLUtm          5-glutamyl-10FTHF transport, mitochondrial
# 10FTHF6GLUtl              6-glutamyl-10FTHF transport, lysosomal
# 10FTHF6GLUtm          6-glutamyl-10FTHF transport, mitochondrial
# 10FTHF7GLUtl              7-glutamyl-10FTHF transport, lysosomal
# ...                                                          ...
# MAL_Lte                                    Transport of L-malate
# OROTGLUt                                                OROTGLUt
# PNTOte                             Transport of (R)-Pantothenate
# IDOURte                     L-iduronate transport, extracellular
# EX_idour(e)                              Exchange of L-iduronate
#
#                                      subsystem  ind_in_original_recon  \
# rxn_code_nodirection
# 10FTHF5GLUtl              Transport, lysosomal                      1
# 10FTHF5GLUtm          Transport, mitochondrial                      2
# 10FTHF6GLUtl              Transport, lysosomal                      3
# 10FTHF6GLUtm          Transport, mitochondrial                      4
# 10FTHF7GLUtl              Transport, lysosomal                      5
# ...                                        ...                    ...
# MAL_Lte               Transport, extracellular                   7436
# OROTGLUt              Transport, extracellular                   7437
# PNTOte                Transport, extracellular                   7438
# IDOURte               Transport, extracellular                   7439
# EX_idour(e)           Exchange/demand reaction                   7440
#
#                      rxn_EC_number genes_associated_with_rxn  \
# rxn_code_nodirection
# 10FTHF5GLUtl                   NaN                       NaN
# 10FTHF5GLUtm                   NaN                       NaN
# 10FTHF6GLUtl                   NaN                       NaN
# 10FTHF6GLUtm                   NaN                       NaN
# 10FTHF7GLUtl                   NaN                       NaN
# ...                            ...                       ...
# MAL_Lte                        NaN                       NaN
# OROTGLUt                       NaN                   SLC22A7
# PNTOte                         NaN                       NaN
# IDOURte                        NaN                       NaN
# EX_idour(e)                    NaN                       NaN
#
#                                                             rxn_formula  \
# rxn_code_nodirection
# 10FTHF5GLUtl          1.00 * 10-formyltetrahydrofolate-[Glu](5) [c] ...
# 10FTHF5GLUtm          1.00 * 10-formyltetrahydrofolate-[Glu](5) [m] ...
# 10FTHF6GLUtl          1.00 * 10-formyltetrahydrofolate-[Glu](6) [c] ...
# 10FTHF6GLUtm          1.00 * 10-formyltetrahydrofolate-[Glu](6) [m] ...
# 10FTHF7GLUtl          1.00 * 10-formyltetrahydrofolate-[Glu](7) [c] ...
# ...                                                                 ...
# MAL_Lte               1.00 * (S)-malate(2-) [e] --> 1.00 * (S)-malat...
# OROTGLUt              1.00 * L-glutamate(1-) [c] + 1.00 * Orotate [e...
# PNTOte                1.00 * (R)-Pantothenate [e] --> 1.00 * (R)-Pan...
# IDOURte               1.00 * L-iduronate [e] --> 1.00 * L-iduronate ...
# EX_idour(e)                      1.00 * L-iduronate [e] --> ϕ\nNo genes
#
#                       rxn_confidence
# rxn_code_nodirection
# 10FTHF5GLUtl                     2.0
# 10FTHF5GLUtm                     2.0
# 10FTHF6GLUtl                     2.0
# 10FTHF6GLUtm                     2.0
# 10FTHF7GLUtl                     2.0
# ...                              ...
# MAL_Lte                          NaN
# OROTGLUt                         NaN
# PNTOte                           NaN
# IDOURte                          NaN
# EX_idour(e)                      NaN
#
# [7440 rows x 7 columns]

# %%
#This function is repeated here for clarity
def get_reaction_consistencies(compass_reaction_penalties, min_range=1e-3):
    """
        Converts the raw penalties outputs of compass into scores per reactions where higher numbers indicate more activity
    """
    df = -np.log(compass_reaction_penalties + 1)
    df = df[df.max(axis=1) - df.min(axis=1) >= min_range]
    df = df - df.min().min()
    return df

# %%
reaction_consistencies = get_reaction_consistencies(reaction_penalties)

# %%
from compass_analysis import cohens_d, wilcoxon_test, get_reaction_consistencies, get_metareactions, labeled_reactions, amino_acid_metab

# %%
reaction_consistencies
# Out:
#                          SRR2921282  SRR2921283  SRR2921284  SRR2921285  \
# 10FTHF5GLUtl_pos           3.560098    3.579258    3.485923    3.584638
# 10FTHF5GLUtm_pos           3.234027    3.244194    3.279274    3.254046
# 10FTHF6GLUtl_pos           3.409903    3.436089    3.310607    3.444044
# 10FTHF6GLUtm_pos           3.207974    3.226635    3.221804    3.237842
# 10FTHF7GLUtl_pos           3.321002    3.350895    3.235614    3.360219
# ...                             ...         ...         ...         ...
# sink_decdicoa(c)_neg       1.985330    2.000964    1.941432    2.027745
# sink_octdececoa(c)_neg     1.700189    1.700909    1.689598    1.741643
# sink_pre_prot(r)_neg       7.563360    7.646562    7.633055    7.614586
# sink_tetdec2coa(c)_neg     1.985330    2.000964    1.941432    2.027745
# sink_tetdece1coa(c)_neg    1.985330    2.000964    1.941432    2.027745
#
#                          SRR2921286  SRR2921287  SRR2921288  SRR2921289  \
# 10FTHF5GLUtl_pos           3.515186    3.558645    3.558489    3.543815
# 10FTHF5GLUtm_pos           3.203246    3.230456    3.323853    3.323872
# 10FTHF6GLUtl_pos           3.348049    3.408090    3.408453    3.395481
# 10FTHF6GLUtm_pos           3.171089    3.201245    3.285225    3.283461
# 10FTHF7GLUtl_pos           3.250377    3.318999    3.343339    3.332772
# ...                             ...         ...         ...         ...
# sink_decdicoa(c)_neg       1.910153    1.986186    1.996023    2.003792
# sink_octdececoa(c)_neg     1.617176    1.672456    1.663766    1.745393
# sink_pre_prot(r)_neg       7.544816    7.629731    7.588375    7.518963
# sink_tetdec2coa(c)_neg     1.910153    1.986186    1.996023    2.003792
# sink_tetdece1coa(c)_neg    1.910153    1.986186    1.996023    2.003792
#
#                          SRR2921290  SRR2921291  ...  SRR2921703  SRR2921704  \
# 10FTHF5GLUtl_pos           3.543955    3.516090  ...    3.519169    3.529113
# 10FTHF5GLUtm_pos           3.311300    3.200736  ...    3.296751    3.286697
# 10FTHF6GLUtl_pos           3.397799    3.349607  ...    3.355255    3.372460
# 10FTHF6GLUtm_pos           3.263414    3.157963  ...    3.242711    3.238099
# 10FTHF7GLUtl_pos           3.330132    3.252261  ...    3.285036    3.306437
# ...                             ...         ...  ...         ...         ...
# sink_decdicoa(c)_neg       1.948791    1.982319  ...    2.063456    2.011850
# sink_octdececoa(c)_neg     1.623148    1.670114  ...    1.757744    1.667850
# sink_pre_prot(r)_neg       7.542433    7.635217  ...    7.618614    7.633269
# sink_tetdec2coa(c)_neg     1.948791    1.982319  ...    2.063456    2.011850
# sink_tetdece1coa(c)_neg    1.948791    1.982319  ...    2.063456    2.011850
#
#                          SRR2921705  SRR2921706  SRR2921707  SRR2921708  \
# 10FTHF5GLUtl_pos           3.505519    3.547540    3.556900    3.541081
# 10FTHF5GLUtm_pos           3.249583    3.287074    3.264088    3.261074
# 10FTHF6GLUtl_pos           3.334797    3.392539    3.405190    3.383008
# 10FTHF6GLUtm_pos           3.203860    3.253589    3.235269    3.222103
# 10FTHF7GLUtl_pos           3.243860    3.316514    3.326009    3.311316
# ...                             ...         ...         ...         ...
# sink_decdicoa(c)_neg       1.990337    2.041585    2.062957    1.998108
# sink_octdececoa(c)_neg     1.721753    1.714890    1.762804    1.724083
# sink_pre_prot(r)_neg       7.537016    7.586845    7.598115    7.576199
# sink_tetdec2coa(c)_neg     1.990337    2.041585    2.062957    1.998108
# sink_tetdece1coa(c)_neg    1.990337    2.041585    2.062957    1.998108
#
#                          SRR2921709  SRR2921710  SRR2921711  SRR2921712
# 10FTHF5GLUtl_pos           3.550715    3.587909    3.556162    3.506701
# 10FTHF5GLUtm_pos           3.216091    3.343650    3.325867    3.192499
# 10FTHF6GLUtl_pos           3.396777    3.457350    3.407172    3.337523
# 10FTHF6GLUtm_pos           3.183784    3.324754    3.283187    3.143835
# 10FTHF7GLUtl_pos           3.305916    3.401467    3.340940    3.238800
# ...                             ...         ...         ...         ...
# sink_decdicoa(c)_neg       2.030832    2.011791    1.969472    2.014824
# sink_octdececoa(c)_neg     1.655184    1.684556    1.621820    1.754615
# sink_pre_prot(r)_neg       7.690232    7.571615    7.576723    7.546652
# sink_tetdec2coa(c)_neg     2.030832    2.011791    1.969472    2.014824
# sink_tetdece1coa(c)_neg    2.030832    2.011791    1.969472    2.014824
#
# [6373 rows x 290 columns]

# %%
cell_metadata = pd.read_csv(scrna_metadata_file, sep=',', index_col=0)
cell_metadata
# Out:
#            cell_type      MD_SRX   NREADS  NALIGNED   RALIGN
# cell_id
# SRR2921282     Th17p  SRX1435506   637389    396663  62.2325
# SRR2921283     Th17p  SRX1435507  1074300    732092  68.1459
# SRR2921284     Th17p  SRX1435508  1480810   1085800  73.3252
# SRR2921285     Th17p  SRX1435509  1374340    982010  71.4531
# SRR2921286     Th17p  SRX1435510  1243850    921003  74.0444
# ...              ...         ...      ...       ...      ...
# SRR2921708     Th17n  SRX1435924  2500130   1701980  68.0755
# SRR2921709     Th17n  SRX1435925  3024280   2098810  69.3988
# SRR2921710     Th17n  SRX1435926  2853240   1622680  56.8715
# SRR2921711     Th17n  SRX1435927  2508770   1518530  60.5291
# SRR2921712     Th17n  SRX1435928  2978350   2003290  67.2619
#
# [290 rows x 5 columns]

# %%
Th17p_cells = cell_metadata.index[cell_metadata['cell_type'] == 'Th17p']
Th17n_cells = cell_metadata.index[cell_metadata['cell_type'] == 'Th17n']

# %%
# Th17p_Vehicle = scrna_metadata[scrna_metadata['cell_type'] == 'Th17p'].index
# print(Th17p_Vehicle)
# Th17n_Vehicle = scrna_metadata[scrna_metadata['cell_type'] == 'Th17n'].index
# print(Th17n_Vehicle)

# %%
wilcox_results = wilcoxon_test(reaction_consistencies, Th17p_cells, Th17n_cells)
wilcox_results['metadata_r_id'] = ""
for r in wilcox_results.index:
    if r in reaction_metadata.index:
        wilcox_results.loc[r, 'metadata_r_id'] = r
    elif r[:-4] in reaction_metadata.index:
        wilcox_results.loc[r, 'metadata_r_id'] = r[:-4]
    else:
        print("Should not occur")

# %%
wilcox_results
# Out:
#                          wilcox_stat  wilcox_pval  cohens_d  adjusted_pval  \
# 10FTHF5GLUtl_pos             12986.0     0.000480  0.402616       0.002237
# 10FTHF5GLUtm_pos             10555.0     0.932976  0.028854       0.950273
# 10FTHF6GLUtl_pos             12889.0     0.000792  0.374953       0.003426
# 10FTHF6GLUtm_pos             10885.0     0.584616  0.082620       0.711158
# 10FTHF7GLUtl_pos             12542.0     0.004115  0.322142       0.013098
# ...                              ...          ...       ...            ...
# sink_decdicoa(c)_neg          9015.0     0.038165 -0.196656       0.077116
# sink_octdececoa(c)_neg       10163.0     0.642680 -0.062833       0.733384
# sink_pre_prot(r)_neg         13242.0     0.000118  0.465730       0.000681
# sink_tetdec2coa(c)_neg        9015.0     0.038165 -0.196656       0.077116
# sink_tetdece1coa(c)_neg       9015.0     0.038165 -0.196656       0.077116
#
#                                metadata_r_id
# 10FTHF5GLUtl_pos                10FTHF5GLUtl
# 10FTHF5GLUtm_pos                10FTHF5GLUtm
# 10FTHF6GLUtl_pos                10FTHF6GLUtl
# 10FTHF6GLUtm_pos                10FTHF6GLUtm
# 10FTHF7GLUtl_pos                10FTHF7GLUtl
# ...                                      ...
# sink_decdicoa(c)_neg        sink_decdicoa(c)
# sink_octdececoa(c)_neg    sink_octdececoa(c)
# sink_pre_prot(r)_neg        sink_pre_prot(r)
# sink_tetdec2coa(c)_neg    sink_tetdec2coa(c)
# sink_tetdece1coa(c)_neg  sink_tetdece1coa(c)
#
# [6373 rows x 5 columns]

# %%
W = wilcox_results.merge(reaction_metadata, how='left',
                         left_on='metadata_r_id', right_index=True, validate='m:1')
# W = W[W['rxn_confidence'].isin([0,4])]
W = W[W['rxn_confidence'].isin([1,2,3,4])]
W = W[~W['rxn_EC_number'].isna()]
# new
W = W[~W['genes_associated_with_rxn'].isna()]
W.loc[(W['rxn_formula'].map(lambda x: '[m]' not in x)) & (W['subsystem'] == "Citric acid cycle"), 'subsystem'] = 'Other'

# %%
wilcox_results.loc[['r0281_pos']]
# Out:
#            wilcox_stat  wilcox_pval  cohens_d  adjusted_pval metadata_r_id
# r0281_pos       9269.0     0.085969 -0.221507       0.153082         r0281

# %%
reaction_metadata.loc['r0281']['rxn_formula']
# Out:
# '1.00 * Water [e] + 1.00 * O2 [e] + 1.00 * Putrescine [e] --> 1.00 * Ammonium [e] + 1.00 * Hydrogen peroxide [e] + 1.00 * 4-Aminobutanal [e]\nAOC1'

# %%
W[W['adjusted_pval']<0.05].sort_values(by=['adjusted_pval'])
# Out:
#                 wilcox_stat   wilcox_pval  cohens_d  adjusted_pval  \
# NADNe_pos              69.0  3.297642e-52 -2.184415   3.002268e-49
# NADPNe_pos             69.0  3.297642e-52 -2.184415   3.002268e-49
# FACOAL1821_neg       3491.0  9.612729e-23 -1.211433   3.603642e-20
# RNDR1_pos            3878.0  1.801330e-20 -0.406287   4.415337e-18
# RNDR4_pos            3936.0  3.848723e-20 -0.369379   7.432701e-18
# ...                     ...           ...       ...            ...
# OIVD2m_pos          12185.0  1.784417e-02  0.280616   4.466650e-02
# HIBDm_pos           12185.0  1.784417e-02  0.280616   4.466650e-02
# 2HBO_pos            12183.0  1.797987e-02  0.405221   4.497084e-02
# NBAHH_ir_pos        12165.0  1.924236e-02  0.247134   4.723865e-02
# P45027A15m_pos      12164.0  1.931471e-02  0.213556   4.737978e-02
#
#                metadata_r_id  \
# NADNe_pos              NADNe
# NADPNe_pos            NADPNe
# FACOAL1821_neg    FACOAL1821
# RNDR1_pos              RNDR1
# RNDR4_pos              RNDR4
# ...                      ...
# OIVD2m_pos            OIVD2m
# HIBDm_pos              HIBDm
# 2HBO_pos                2HBO
# NBAHH_ir_pos        NBAHH_ir
# P45027A15m_pos    P45027A15m
#
#                                                     rxn_name_long  \
# NADNe_pos                          NAD nucleosidase,extracellular
# NADPNe_pos                        NADP nucleosidase,extracellular
# FACOAL1821_neg                             fatty-acid--CoA ligase
# RNDR1_pos              ribonucleoside-diphosphate reductase (ADP)
# RNDR4_pos              ribonucleoside-diphosphate reductase (UDP)
# ...                                                           ...
# OIVD2m_pos      2-oxoisovalerate dehydrogenase (acylating; 3-m...
# HIBDm_pos       3-hydroxyisobutyrate dehydrogenase, mitochondrial
# 2HBO_pos                    2-Hydroxybutyrate:NAD+ oxidoreductase
# NBAHH_ir_pos        Nalpha-(beta-alanyl)-L-histidine hydrolase IR
# P45027A15m_pos  5-beta-cytochrome P450, family 27, subfamily A...
#
#                                                  subsystem  \
# NADNe_pos                                   NAD metabolism
# NADPNe_pos                                  NAD metabolism
# FACOAL1821_neg                        Fatty acid oxidation
# RNDR1_pos                       Nucleotide interconversion
# RNDR4_pos                       Nucleotide interconversion
# ...                                                    ...
# OIVD2m_pos      Valine, leucine, and isoleucine metabolism
# HIBDm_pos       Valine, leucine, and isoleucine metabolism
# 2HBO_pos                             Propanoate metabolism
# NBAHH_ir_pos                       beta-Alanine metabolism
# P45027A15m_pos                         Bile acid synthesis
#
#                 ind_in_original_recon rxn_EC_number  \
# NADNe_pos                        2671       3.2.2.5
# NADPNe_pos                       2675       3.2.2.6
# FACOAL1821_neg                   1627       6.2.1.3
# RNDR1_pos                        3208      1.7.14.1
# RNDR4_pos                        3211      1.7.14.1
# ...                               ...           ...
# OIVD2m_pos                       2831       1.8.1.4
# HIBDm_pos                        2236      1.1.1.31
# 2HBO_pos                           41      1.1.1.27
# NBAHH_ir_pos                     2694      3.4.13.3
# P45027A15m_pos                   2866    1.14.13.15
#
#                        genes_associated_with_rxn  \
# NADNe_pos                                   CD38
# NADPNe_pos                                  CD38
# FACOAL1821_neg       ACSBG2; ACSL1; ACSL3; ACSL4
# RNDR1_pos                      RRM1; RRM2; RRM2B
# RNDR4_pos                      RRM1; RRM2; RRM2B
# ...                                          ...
# OIVD2m_pos              BCKDHA; BCKDHB; DBT; DLD
# HIBDm_pos                                 HIBADH
# 2HBO_pos        LDHA; LDHAL6B; LDHB; LDHC; UEVLD
# NBAHH_ir_pos                        CNDP1; CNDP2
# P45027A15m_pos                           CYP27A1
#
#                                                       rxn_formula  \
# NADNe_pos       1.00 * Water [e] + 1.00 * Nicotinamide adenine...
# NADPNe_pos      1.00 * Water [e] + 1.00 * Nicotinamide adenine...
# FACOAL1821_neg  1.00 * ATP [c] + 1.00 * Coenzyme A [c] + 1.00 ...
# RNDR1_pos       1.00 * ADP [c] + 1.00 * Reduced thioredoxin [c...
# RNDR4_pos       1.00 * UDP [c] + 1.00 * Reduced thioredoxin [c...
# ...                                                           ...
# OIVD2m_pos      1.00 * Coenzyme A [m] + 1.00 * Nicotinamide ad...
# HIBDm_pos       1.00 * Nicotinamide adenine dinucleotide [m] +...
# 2HBO_pos        1.00 * 2-Hydroxybutyrate [c] + 1.00 * Nicotina...
# NBAHH_ir_pos    1.00 * Water [c] + 1.00 * carnosine [c] --> 1....
# P45027A15m_pos  1.00 * proton [m] + 1.00 * Nicotinamide adenin...
#
#                 rxn_confidence
# NADNe_pos                  4.0
# NADPNe_pos                 4.0
# FACOAL1821_neg             4.0
# RNDR1_pos                  2.0
# RNDR4_pos                  2.0
# ...                        ...
# OIVD2m_pos                 4.0
# HIBDm_pos                  4.0
# 2HBO_pos                   4.0
# NBAHH_ir_pos               1.0
# P45027A15m_pos             4.0
#
# [472 rows x 12 columns]

# %%
W[W['adjusted_pval']<0.05]['subsystem'].value_counts()
# Out:
# Nucleotide interconversion                           57
# Fatty acid oxidation                                 40
# Sphingolipid metabolism                              40
# Tyrosine metabolism                                  21
# Blood group synthesis                                20
# Folate metabolism                                    20
# Pyrimidine catabolism                                18
# Cholesterol metabolism                               17
# Valine, leucine, and isoleucine metabolism           16
# Purine catabolism                                    12
# Bile acid synthesis                                  11
# Glycerophospholipid metabolism                       11
# Arginine and Proline Metabolism                      10
# Aminosugar metabolism                                10
# Pentose phosphate pathway                            10
# Pyruvate metabolism                                   9
# Inositol phosphate metabolism                         9
# Urea cycle                                            9
# Vitamin A metabolism                                  8
# C5-branched dibasic acid metabolism                   8
# Purine synthesis                                      7
# NAD metabolism                                        7
# Glycine, serine, alanine and threonine metabolism     7
# Methionine and cysteine metabolism                    7
# Tryptophan metabolism                                 6
# Glutathione metabolism                                6
# Steroid metabolism                                    6
# Glyoxylate and dicarboxylate metabolism               5
# Pyrimidine synthesis                                  5
# Triacylglycerol synthesis                             5
# Glutamate metabolism                                  4
# Alanine and aspartate metabolism                      4
# Fatty acid synthesis                                  3
# Keratan sulfate degradation                           3
# Propanoate metabolism                                 3
# beta-Alanine metabolism                               3
# N-glycan degradation                                  3
# Nucleotide salvage pathway                            3
# Glycolysis/gluconeogenesis                            3
# Cytochrome metabolism                                 2
# Transport, extracellular                              2
# Fructose and mannose metabolism                       2
# Oxidative phosphorylation                             2
# Eicosanoid metabolism                                 2
# Miscellaneous                                         2
# Phosphatidylinositol phosphate metabolism             2
# Lysine metabolism                                     2
# Butanoate metabolism                                  2
# Histidine metabolism                                  1
# N-glycan synthesis                                    1
# Ubiquinone synthesis                                  1
# Other                                                 1
# D-alanine metabolism                                  1
# Starch and sucrose metabolism                         1
# Transport, mitochondrial                              1
# Thiamine metabolism                                   1
# Name: subsystem, dtype: int64

# %%
gene_set_all = []
for gene_list in W[W['adjusted_pval']<0.05]['genes_associated_with_rxn'].values:
    if type(gene_list) is not float:
        gene_set_all.extend(gene_list.split('; '))
print(len(gene_set_all))
# Out:
# 868

# %%
from collections import Counter
Counter(gene_set_all).most_common()
# Out:
# [('ACSL1', 20),
#  ('PNP2', 15),
#  ('GM20390', 13),
#  ('NME2', 13),
#  ('FUT9', 11),
#  ('NT5C', 11),
#  ('NT5C3', 10),
#  ('NT5E', 10),
#  ('CRAT', 9),
#  ('FPGS', 9),
#  ('SUCLG1', 8),
#  ('NT5C1A', 8),
#  ('NT5C1B', 8),
#  ('NT5C2', 8),
#  ('ST6GALNAC2', 8),
#  ('ALDH3B1', 7),
#  ('FUT1', 7),
#  ('NME6', 7),
#  ('ALDH3A1', 6),
#  ('ALDH3B3', 6),
#  ('AKR7A5', 6),
#  ('EHHADH', 6),
#  ('ST8SIA5', 6),
#  ('ADH1', 5),
#  ('ADH4', 5),
#  ('ADH5', 5),
#  ('ADH6A', 5),
#  ('ADH7', 5),
#  ('ADHFE1', 5),
#  ('ALDH1A3', 5),
#  ('ACAA1B', 5),
#  ('ACOX1', 5),
#  ('HSD17B4', 5),
#  ('BCAT2', 5),
#  ('MTHFD2', 5),
#  ('UGT1A8', 5),
#  ('LDHA', 4),
#  ('LDHAL6B', 4),
#  ('LDHB', 4),
#  ('LDHC', 4),
#  ('GOT2', 4),
#  ('ATIC', 4),
#  ('ZADH2', 4),
#  ('AKR1A1', 4),
#  ('AKR1B3', 4),
#  ('B3GALT4', 4),
#  ('AICDA', 4),
#  ('DCK', 4),
#  ('SLC27A2', 4),
#  ('MTHFD1', 4),
#  ('CTSA', 4),
#  ('GALNS', 4),
#  ('GLB1', 4),
#  ('NEU1', 4),
#  ('B4GALNT1', 4),
#  ('SUCLG2', 4),
#  ('SUCLA2', 4),
#  ('NME3', 4),
#  ('NME7', 4),
#  ('NME4', 4),
#  ('RRM1', 4),
#  ('RRM2', 4),
#  ('RRM2B', 4),
#  ('UEVLD', 3),
#  ('DDC', 3),
#  ('ALDH4A1', 3),
#  ('ACSL3', 3),
#  ('MTHFD1L', 3),
#  ('LDHD', 3),
#  ('PGD', 3),
#  ('BCAT1', 3),
#  ('LIPC', 3),
#  ('MTHFR', 3),
#  ('CYP27A1', 3),
#  ('PYCR1', 3),
#  ('RDH5', 3),
#  ('RDH11', 3),
#  ('RDH12', 3),
#  ('RDH13', 3),
#  ('RDH14', 3),
#  ('SDR16C5', 3),
#  ('ABAT', 2),
#  ('MAOA', 2),
#  ('MAOB', 2),
#  ('NANS', 2),
#  ('ACAD8', 2),
#  ('ACADM', 2),
#  ('AK5', 2),
#  ('MBOAT2', 2),
#  ('AGXT', 2),
#  ('PROSC', 2),
#  ('ANPEP', 2),
#  ('ARG2', 2),
#  ('CAD', 2),
#  ('ENTPD5', 2),
#  ('UPB1', 2),
#  ('CMAS', 2),
#  ('CDA', 2),
#  ('ADA', 2),
#  ('DCTD', 2),
#  ('FADS2', 2),
#  ('DHCR7', 2),
#  ('DPYS', 2),
#  ('GGPS1', 2),
#  ('FDPS', 2),
#  ('DPYD', 2),
#  ('ACSBG2', 2),
#  ('ACSL4', 2),
#  ('ALDH18A1', 2),
#  ('G6PC', 2),
#  ('G6PC2', 2),
#  ('G6PC3', 2),
#  ('GRHPR', 2),
#  ('GSR', 2),
#  ('GPX1', 2),
#  ('GPX2', 2),
#  ('HPRT', 2),
#  ('HSD17B7', 2),
#  ('KYNU', 2),
#  ('LPL', 2),
#  ('SC5D', 2),
#  ('CYP7A1', 2),
#  ('AUH', 2),
#  ('MTHFD2L', 2),
#  ('CD38', 2),
#  ('NAGA', 2),
#  ('ENTPD4', 2),
#  ('BCKDHA', 2),
#  ('BCKDHB', 2),
#  ('DBT', 2),
#  ('DLD', 2),
#  ('UMPS', 2),
#  ('OAT', 2),
#  ('PI4K2A', 2),
#  ('PI4KA', 2),
#  ('PI4KB', 2),
#  ('PLA2G12A', 2),
#  ('PLA2G2A', 2),
#  ('PLA2G2F', 2),
#  ('PLA2G5', 2),
#  ('PRODH2', 2),
#  ('PTDSS2', 2),
#  ('UPP1', 2),
#  ('UPP2', 2),
#  ('RDH8', 2),
#  ('RPE', 2),
#  ('ST3GAL2', 2),
#  ('ST8SIA1', 2),
#  ('TYMP', 2),
#  ('GALE', 2),
#  ('UGT1A1', 2),
#  ('UGT1A2', 2),
#  ('UGT1A7C', 2),
#  ('XDH', 2),
#  ('DCXR', 2),
#  ('HPD', 1),
#  ('KDSR', 1),
#  ('ECHDC2', 1),
#  ('GOT1', 1),
#  ('AOX1', 1),
#  ('A4GALT', 1),
#  ('AADAT', 1),
#  ('ACSS2', 1),
#  ('RENBP', 1),
#  ('PIGL', 1),
#  ('ACP5', 1),
#  ('ACP6', 1),
#  ('NANP', 1),
#  ('IVD', 1),
#  ('ACOX2', 1),
#  ('ACYP1', 1),
#  ('ACYP2', 1),
#  ('RWDD2A', 1),
#  ('NUDT5', 1),
#  ('APRT', 1),
#  ('ADSL', 1),
#  ('AGMAT', 1),
#  ('AGPAT1', 1),
#  ('AGPAT2', 1),
#  ('AGPAT3', 1),
#  ('AGPAT4', 1),
#  ('AGPAT5', 1),
#  ('GPAT4', 1),
#  ('AHCYL1', 1),
#  ('GM4737', 1),
#  ('HEXA', 1),
#  ('HEXB', 1),
#  ('AKR1D1', 1),
#  ('ALAS1', 1),
#  ('ALAS2', 1),
#  ('GCAT', 1),
#  ('GPT', 1),
#  ('GPT2', 1),
#  ('ALOX5', 1),
#  ('AMACR', 1),
#  ('GNE', 1),
#  ('NAGK', 1),
#  ('AMPD1', 1),
#  ('AMPD2', 1),
#  ('AMPD3', 1),
#  ('AZIN2', 1),
#  ('ARG1', 1),
#  ('ASAH1', 1),
#  ('ASRGL1', 1),
#  ('ENTPD1', 1),
#  ('ENTPD2', 1),
#  ('ENTPD3', 1),
#  ('ENTPD6', 1),
#  ('ATP5A1', 1),
#  ('ATP5B', 1),
#  ('ATP5C1', 1),
#  ('ATP5D', 1),
#  ('ATP5E', 1),
#  ('ATP5F1', 1),
#  ('ATP5G1', 1),
#  ('ATP5G2', 1),
#  ('ATP5G3', 1),
#  ('ATP5H', 1),
#  ('ATP5J', 1),
#  ('ATP5J2', 1),
#  ('ATP5K', 1),
#  ('ATP5O', 1),
#  ('ATP5S', 1),
#  ('GM5426', 1),
#  ('NSF', 1),
#  ('B3GALNT1', 1),
#  ('BAAT', 1),
#  ('BDH1', 1),
#  ('TM7SF2', 1),
#  ('CPT1A', 1),
#  ('CPT1B', 1),
#  ('CPT1C', 1),
#  ('CAT', 1),
#  ('CDIPT', 1),
#  ('CKMT1', 1),
#  ('CKMT2', 1),
#  ('CKB', 1),
#  ('CKM', 1),
#  ('CTH', 1),
#  ('CBS', 1),
#  ('DAO', 1),
#  ('SCD4', 1),
#  ('DGUOK', 1),
#  ('COQ3', 1),
#  ('DHFR', 1),
#  ('DHODH', 1),
#  ('DPYSL2', 1),
#  ('DPYSL3', 1),
#  ('DBH', 1),
#  ('MOXD1', 1),
#  ('MVD', 1),
#  ('DERA', 1),
#  ('TK1', 1),
#  ('TK2', 1),
#  ('DUT', 1),
#  ('CHKA', 1),
#  ('CHKB', 1),
#  ('ETNK1', 1),
#  ('ETNK2', 1),
#  ('ACSL5', 1),
#  ('ACSL6', 1),
#  ('ACSM1', 1),
#  ('ALDH1L1', 1),
#  ('AFMID', 1),
#  ('MTHFSL', 1),
#  ('FUCA2', 1),
#  ('FAH', 1),
#  ('B4GALT1', 1),
#  ('B4GALT2', 1),
#  ('B4GALT3', 1),
#  ('B4GALT5', 1),
#  ('GNPDA1', 1),
#  ('GNPDA2', 1),
#  ('GAL3ST1', 1),
#  ('GALC', 1),
#  ('GART', 1),
#  ('GBA', 1),
#  ('GBGT1', 1),
#  ('GCNT2', 1),
#  ('GGCT', 1),
#  ('SHMT1', 1),
#  ('PPAT', 1),
#  ('HAO1', 1),
#  ('HAO2', 1),
#  ('GK', 1),
#  ('GK2', 1),
#  ('GMPR', 1),
#  ('GMPR2', 1),
#  ('GPAM', 1),
#  ('GPX4', 1),
#  ('PRDX1', 1),
#  ('PRDX2', 1),
#  ('GPX3', 1),
#  ('GPX6', 1),
#  ('GPX7', 1),
#  ('GGT1', 1),
#  ('GDA', 1),
#  ('HGD', 1),
#  ('HIBADH', 1),
#  ('HDC', 1),
#  ('ATP4A', 1),
#  ('ATP4B', 1),
#  ('HMGCS1', 1),
#  ('H2-KE6', 1),
#  ('HSD17B1', 1),
#  ('IDH1', 1),
#  ('IMPDH1', 1),
#  ('IMPDH2', 1),
#  ('MIOX', 1),
#  ('GM9745', 1),
#  ('IDI1', 1),
#  ('LSS', 1),
#  ('MGLL', 1),
#  ('CEL', 1),
#  ('PNPLA3', 1),
#  ('LIPF', 1),
#  ('LIPG', 1),
#  ('PNLIP', 1),
#  ('PNLIPRP1', 1),
#  ('PNLIPRP2', 1),
#  ('LTA4H', 1),
#  ('GSTZ1', 1),
#  ('GAA', 1),
#  ('GANC', 1),
#  ('MGAM', 1),
#  ('MPI', 1),
#  ('MCCC1', 1),
#  ('MCCC2', 1),
#  ('CYP1A1', 1),
#  ('CYP1A2', 1),
#  ('CYP1B1', 1),
#  ('MTR', 1),
#  ('MVK', 1),
#  ('INPP5A', 1),
#  ('INPP5B', 1),
#  ('INPP5D', 1),
#  ('INPP5E', 1),
#  ('INPP5J', 1),
#  ('INPPL1', 1),
#  ('SYNJ1', 1),
#  ('INPP1', 1),
#  ('ITPKA', 1),
#  ('ITPKB', 1),
#  ('ITPKC', 1),
#  ('ISYNA1', 1),
#  ('INPP4A', 1),
#  ('INPP4B', 1),
#  ('IMPA1', 1),
#  ('IMPA2', 1),
#  ('CNDP1', 1),
#  ('CNDP2', 1),
#  ('DCTPP1', 1),
#  ('CANT1', 1),
#  ('DTYMK', 1),
#  ('PNMT', 1),
#  ('SULT1A1', 1),
#  ('OTC', 1),
#  ('CYP2A4', 1),
#  ('CYP2C55', 1),
#  ('PYCR2', 1),
#  ('PYCRL', 1),
#  ('ATP10A', 1),
#  ('PCYT2', 1),
#  ('PEMT', 1),
#  ('PHGDH', 1),
#  ('PGLS', 1),
#  ('H6PD', 1),
#  ('PGS1', 1),
#  ('DPM2', 1),
#  ('PIGA', 1),
#  ('PIGC', 1),
#  ('PIGH', 1),
#  ('PIGP', 1),
#  ('PIGQ', 1),
#  ('HCST', 1),
#  ('PIK3C2A', 1),
#  ('PIK3C2B', 1),
#  ('PIK3C2G', 1),
#  ('PIK3C3', 1),
#  ('PIK3CA', 1),
#  ('PIK3CB', 1),
#  ('PIK3CD', 1),
#  ('PIK3CG', 1),
#  ('PIK3R1', 1),
#  ('PIK3R2', 1),
#  ('PIK3R3', 1),
#  ('PIK3R5', 1),
#  ('PLA2G3', 1),
#  ('PLA2G4A', 1),
#  ('PLA2G4B', 1),
#  ('PLA2G4E', 1),
#  ('PLA2G6', 1),
#  ('PLA2G10', 1),
#  ('PLA2G1B', 1),
#  ('PLA2G2D', 1),
#  ('PLA2G2E', 1),
#  ('PMVK', 1),
#  ('LHPP', 1),
#  ('PPA1', 1),
#  ('ACAD11', 1),
#  ('ACAD12', 1),
#  ('ACAD9', 1),
#  ('ACADS', 1),
#  ('ACADSB', 1),
#  ('ECHS1', 1),
#  ('HADHA', 1),
#  ('HADHB', 1),
#  ('PSAT1', 1),
#  ('PSPH', 1),
#  ('RDH16F1', 1),
#  ('RDH10', 1),
#  ('NMRK1', 1),
#  ('AASS', 1),
#  ('COMTD1', 1),
#  ('SPTLC1', 1),
#  ('SPTLC2', 1),
#  ('SPTLC3', 1),
#  ('SGPL1', 1),
#  ('ST3GAL5', 1),
#  ('SQLE', 1),
#  ('FDFT1', 1),
#  ('ST3GAL3', 1),
#  ('NNT', 1),
#  ('THTPA', 1),
#  ('SDS', 1),
#  ('SDSL', 1),
#  ('TYMS', 1),
#  ('TXNRD2', 1),
#  ('TXNRD3', 1),
#  ('IDO1', 1),
#  ('IDO2', 1),
#  ('TDO2', 1),
#  ('TAT', 1),
#  ('UGCG', 1),
#  ('UGT2B34', 1),
#  ('SLC27A5', 1)]

# %%
W['subsystem'].value_counts()
# Out:
# Nucleotide interconversion     174
# Fatty acid oxidation           145
# Keratan sulfate degradation     59
# Sphingolipid metabolism         44
# Tyrosine metabolism             41
#                               ...
# Ubiquinone synthesis             1
# Vitamin C metabolism             1
# CoA synthesis                    1
# O-glycan synthesis               1
# Thiamine metabolism              1
# Name: subsystem, Length: 75, dtype: int64

# %%
# only significant
data = W[~W['subsystem'].isin(["Miscellaneous", "Unassigned"])]
data = data[~data['subsystem'].map(lambda x: "Transport" in x or "Exchange" in x or x == "Other")]
items, counts = np.unique(data['subsystem'], return_counts=True)
items = [items[i] for i in range(len(items)) if counts[i] > 5] #filter(n() > 5) %>%
data = data[data['subsystem'].isin(items)]
data = data[data['adjusted_pval'] < 0.05]
plt.figure(figsize=(12,12))
axs = plt.gca()
#Sorts the reactions for plotting
d = data[data['adjusted_pval'] < 0.05].groupby('subsystem')['cohens_d'].median().abs()
axs.scatter(d[d.argsort], d[d.argsort].index, alpha=0)
color = data['cohens_d'].map(lambda x: 'r' if x >= 0 else 'b')
alpha = data['adjusted_pval'].map(lambda x: 1.0 if x < 0.1 else 0.25)
axs.scatter(data['cohens_d'], data['subsystem'], c=color, alpha=alpha)
axs.set_xlabel("Cohen's d")
axs.vlines(x=0, ymin=-2, ymax=50, linestyles='--')

# %%
# all p values plotted
data = W[~W['subsystem'].isin(["Miscellaneous", "Unassigned"])]
data = data[~data['subsystem'].map(lambda x: "Transport" in x or "Exchange" in x or x == "Other")]
items, counts = np.unique(data['subsystem'], return_counts=True)
items = [items[i] for i in range(len(items)) if counts[i] > 5] #filter(n() > 5) %>%
data = data[data['subsystem'].isin(items)]
plt.figure(figsize=(12,12))
axs = plt.gca()
#Sorts the reactions for plotting
d = data[data['adjusted_pval'] < 0.05].groupby('subsystem')['cohens_d'].median().abs()
axs.scatter(d[d.argsort], d[d.argsort].index, alpha=0)
color = data['cohens_d'].map(lambda x: 'r' if x >= 0 else 'b')
alpha = data['adjusted_pval'].map(lambda x: 1.0 if x < 0.1 else 0.25)
axs.scatter(data['cohens_d'], data['subsystem'], c=color, alpha=alpha)
axs.set_xlabel("Cohen's d")
axs.vlines(x=0, ymin=-2, ymax=50, linestyles='--')
#axs.set_xlim(-0.8,.8)

# %%
print(data[data['adjusted_pval'] < 0.05].groupby('subsystem')['cohens_d'].quantile([.25]))
# Out:
# subsystem
# Alanine and aspartate metabolism                   0.25    0.314044
# Aminosugar metabolism                              0.25    0.404578
# Arginine and Proline Metabolism                    0.25    0.134627
# Bile acid synthesis                                0.25    0.312911
# Blood group synthesis                              0.25    0.603557
# C5-branched dibasic acid metabolism                0.25    0.170517
# Cholesterol metabolism                             0.25    0.307112
# Eicosanoid metabolism                              0.25    0.031949
# Fatty acid oxidation                               0.25   -0.516402
# Fatty acid synthesis                               0.25   -0.611642
# Folate metabolism                                  0.25    0.374977
# Fructose and mannose metabolism                    0.25    0.415597
# Glutamate metabolism                               0.25    0.289909
# Glutathione metabolism                             0.25    0.386944
# Glycerophospholipid metabolism                     0.25    0.287800
# Glycine, serine, alanine and threonine metabolism  0.25    0.341663
# Glycolysis/gluconeogenesis                         0.25    0.156197
# Glyoxylate and dicarboxylate metabolism            0.25   -0.461647
# Histidine metabolism                               0.25    0.285202
# Inositol phosphate metabolism                      0.25    0.395863
# Keratan sulfate degradation                        0.25    0.432843
# Lysine metabolism                                  0.25    0.237244
# Methionine and cysteine metabolism                 0.25    0.582987
# NAD metabolism                                     0.25   -0.900255
# Nucleotide interconversion                         0.25   -0.246481
# Pentose phosphate pathway                          0.25    0.363070
# Propanoate metabolism                              0.25    0.352906
# Purine catabolism                                  0.25    0.388889
# Purine synthesis                                   0.25    0.474111
# Pyrimidine catabolism                              0.25    0.558513
# Pyrimidine synthesis                               0.25    0.626501
# Pyruvate metabolism                                0.25    0.307476
# Sphingolipid metabolism                            0.25    0.437582
# Starch and sucrose metabolism                      0.25    0.455199
# Steroid metabolism                                 0.25   -0.234690
# Triacylglycerol synthesis                          0.25    0.377313
# Tryptophan metabolism                              0.25   -0.420820
# Tyrosine metabolism                                0.25    0.365011
# Urea cycle                                         0.25   -0.406425
# Valine, leucine, and isoleucine metabolism         0.25    0.220114
# Vitamin A metabolism                               0.25    0.167703
# beta-Alanine metabolism                            0.25    0.274023
# Name: cohens_d, dtype: float64

# %% [markdown]
# # compare results to hypergeom test

# %%
#data.to_csv(out_dir + 'compass_results_data.csv')

# %%
# data = pd.read_csv(out_dir + 'compass_results_data.csv', index_col = 0)
data
# Out:
#                  wilcox_stat   wilcox_pval  cohens_d  adjusted_pval  \
# 13DAMPPOX_pos         9130.0  5.589046e-02 -0.214296   1.047309e-01
# 2HBO_neg             10600.0  8.829930e-01  0.093878   9.156059e-01
# 2HBO_pos             12183.0  1.797987e-02  0.405221   4.497084e-02
# 2OXOADOXm_pos         9464.0  1.488154e-01 -0.155247   2.446223e-01
# 34DHOXPEGOX_pos      14828.0  1.251748e-09  0.762535   5.081141e-08
# ...                      ...           ...       ...            ...
# XAO2x_pos            11698.0  9.175370e-02  0.179876   1.621143e-01
# XAOx_pos             12678.0  2.214382e-03  0.350214   8.009227e-03
# XYLK_pos             11561.0  1.351263e-01  0.122613   2.268598e-01
# XYLUR_neg            13525.0  2.165705e-05  0.136831   1.584620e-04
# XYLUR_pos            13636.0  1.069265e-05  0.173212   8.528690e-05
#
#                 metadata_r_id  \
# 13DAMPPOX_pos       13DAMPPOX
# 2HBO_neg                 2HBO
# 2HBO_pos                 2HBO
# 2OXOADOXm_pos       2OXOADOXm
# 34DHOXPEGOX_pos   34DHOXPEGOX
# ...                       ...
# XAO2x_pos               XAO2x
# XAOx_pos                 XAOx
# XYLK_pos                 XYLK
# XYLUR_neg               XYLUR
# XYLUR_pos               XYLUR
#
#                                                      rxn_name_long  \
# 13DAMPPOX_pos    1,3-Diaminopropane:oxygen oxidoreductase (deam...
# 2HBO_neg                     2-Hydroxybutyrate:NAD+ oxidoreductase
# 2HBO_pos                     2-Hydroxybutyrate:NAD+ oxidoreductase
# 2OXOADOXm_pos    2-Oxoadipate:lipoamde 2-oxidoreductase(decarbo...
# 34DHOXPEGOX_pos  3,4-Dihydroxyphenylethyleneglycol:NAD+ oxidore...
# ...                                                            ...
# XAO2x_pos                                         xanthine oxidase
# XAOx_pos                             xanthine  oxidase,peroxisomal
# XYLK_pos                                              xylulokinase
# XYLUR_neg                                       xylulose reductase
# XYLUR_pos                                       xylulose reductase
#
#                                  subsystem  ind_in_original_recon  \
# 13DAMPPOX_pos      beta-Alanine metabolism                     13
# 2HBO_neg             Propanoate metabolism                     41
# 2HBO_pos             Propanoate metabolism                     41
# 2OXOADOXm_pos            Lysine metabolism                     45
# 34DHOXPEGOX_pos        Tyrosine metabolism                     47
# ...                                    ...                    ...
# XAO2x_pos                Purine catabolism                   3711
# XAOx_pos                 Purine catabolism                   3712
# XYLK_pos         Pentose phosphate pathway                   3730
# XYLUR_neg        Pentose phosphate pathway                   3736
# XYLUR_pos        Pentose phosphate pathway                   3736
#
#                 rxn_EC_number              genes_associated_with_rxn  \
# 13DAMPPOX_pos         1.4.3.6                       AOC1; AOC2; AOC3
# 2HBO_neg             1.1.1.27       LDHA; LDHAL6B; LDHB; LDHC; UEVLD
# 2HBO_pos             1.1.1.27       LDHA; LDHAL6B; LDHB; LDHC; UEVLD
# 2OXOADOXm_pos        2.3.1.61                  DLD; DLST; OGDH; PDHX
# 34DHOXPEGOX_pos       1.1.1.1  ADH1; ADH4; ADH5; ADH6A; ADH7; ADHFE1
# ...                       ...                                    ...
# XAO2x_pos           1.1.1.204                                    XDH
# XAOx_pos            1.1.1.204                                    XDH
# XYLK_pos             2.7.1.17                                   XYLB
# XYLUR_neg            1.1.1.10                                   DCXR
# XYLUR_pos            1.1.1.10                                   DCXR
#
#                                                        rxn_formula  \
# 13DAMPPOX_pos    1.00 * trimethylenediaminium [c] + 1.00 * Wate...
# 2HBO_neg         1.00 * 2-Hydroxybutyrate [c] + 1.00 * Nicotina...
# 2HBO_pos         1.00 * 2-Hydroxybutyrate [c] + 1.00 * Nicotina...
# 2OXOADOXm_pos    1.00 * 2-oxoadipate(2-) [m] + 1.00 * Coenzyme ...
# 34DHOXPEGOX_pos  1.00 * proton [c] + 1.00 * Nicotinamide adenin...
# ...                                                            ...
# XAO2x_pos        1.00 * O2 [x] + 1.00 * Water [x] + 1.00 * Hypo...
# XAOx_pos         1.00 * O2 [x] + 1.00 * Water [x] + 1.00 * Xant...
# XYLK_pos         1.00 * ATP [c] + 1.00 * D-xylulose [c] --> 1.0...
# XYLUR_neg        1.00 * proton [c] + 1.00 * Nicotinamide adenin...
# XYLUR_pos        1.00 * proton [c] + 1.00 * Nicotinamide adenin...
#
#                  rxn_confidence
# 13DAMPPOX_pos               1.0
# 2HBO_neg                    4.0
# 2HBO_pos                    4.0
# 2OXOADOXm_pos               2.0
# 34DHOXPEGOX_pos             4.0
# ...                         ...
# XAO2x_pos                   4.0
# XAOx_pos                    4.0
# XYLK_pos                    4.0
# XYLUR_neg                   4.0
# XYLUR_pos                   4.0
#
# [1147 rows x 12 columns]

# %%
sig_data = data[data['adjusted_pval'] < 0.05]
sig_data
# Out:
#                          wilcox_stat   wilcox_pval  cohens_d  adjusted_pval  \
# 2HBO_pos                     12183.0  1.797987e-02  0.405221   4.497084e-02
# 34DHOXPEGOX_pos              14828.0  1.251748e-09  0.762535   5.081141e-08
# 34DHPLACOX_NADP__neg         12799.0  1.240216e-03  0.365011   4.936849e-03
# 34DHPLACOX_pos               12799.0  1.240216e-03  0.365011   4.936849e-03
# 34DHXMANDACOX_NADP__neg      12799.0  1.240216e-03  0.365011   4.936849e-03
# ...                              ...           ...       ...            ...
# VLCSr_pos                    12916.0  6.901503e-04  0.403316   3.024985e-03
# XANDp_pos                    13767.0  4.511909e-06  0.518148   4.119541e-05
# XAOx_pos                     12678.0  2.214382e-03  0.350214   8.009227e-03
# XYLUR_neg                    13525.0  2.165705e-05  0.136831   1.584620e-04
# XYLUR_pos                    13636.0  1.069265e-05  0.173212   8.528690e-05
#
#                                metadata_r_id  \
# 2HBO_pos                                2HBO
# 34DHOXPEGOX_pos                  34DHOXPEGOX
# 34DHPLACOX_NADP__neg        34DHPLACOX_NADP_
# 34DHPLACOX_pos                    34DHPLACOX
# 34DHXMANDACOX_NADP__neg  34DHXMANDACOX_NADP_
# ...                                      ...
# VLCSr_pos                              VLCSr
# XANDp_pos                              XANDp
# XAOx_pos                                XAOx
# XYLUR_neg                              XYLUR
# XYLUR_pos                              XYLUR
#
#                                                              rxn_name_long  \
# 2HBO_pos                             2-Hydroxybutyrate:NAD+ oxidoreductase
# 34DHOXPEGOX_pos          3,4-Dihydroxyphenylethyleneglycol:NAD+ oxidore...
# 34DHPLACOX_NADP__neg     3,4-Dihydroxyphenylacetaldehyde:NADP+ oxidored...
# 34DHPLACOX_pos           3,4-Dihydroxyphenylacetaldehyde:NAD+ oxidoredu...
# 34DHXMANDACOX_NADP__neg   3,4-Dihydroxymandelaldehyde:NADP+ oxidoreductase
# ...                                                                    ...
# VLCSr_pos                            Very-long-chain-fatty-acid-CoA ligase
# XANDp_pos                              xanthine dehydrogenase, peroxisomal
# XAOx_pos                                     xanthine  oxidase,peroxisomal
# XYLUR_neg                                               xylulose reductase
# XYLUR_pos                                               xylulose reductase
#
#                                          subsystem  ind_in_original_recon  \
# 2HBO_pos                     Propanoate metabolism                     41
# 34DHOXPEGOX_pos                Tyrosine metabolism                     47
# 34DHPLACOX_NADP__neg           Tyrosine metabolism                     52
# 34DHPLACOX_pos                 Tyrosine metabolism                     51
# 34DHXMANDACOX_NADP__neg        Tyrosine metabolism                     54
# ...                                            ...                    ...
# VLCSr_pos                      Bile acid synthesis                   3704
# XANDp_pos                        Purine catabolism                   3709
# XAOx_pos                         Purine catabolism                   3712
# XYLUR_neg                Pentose phosphate pathway                   3736
# XYLUR_pos                Pentose phosphate pathway                   3736
#
#                         rxn_EC_number              genes_associated_with_rxn  \
# 2HBO_pos                     1.1.1.27       LDHA; LDHAL6B; LDHB; LDHC; UEVLD
# 34DHOXPEGOX_pos               1.1.1.1  ADH1; ADH4; ADH5; ADH6A; ADH7; ADHFE1
# 34DHPLACOX_NADP__neg          1.2.1.5              ALDH3A1; ALDH3B1; ALDH3B3
# 34DHPLACOX_pos                1.2.1.5     ALDH1A3; ALDH3A1; ALDH3B1; ALDH3B3
# 34DHXMANDACOX_NADP__neg       1.2.1.5                       ALDH3B1; ALDH3B3
# ...                               ...                                    ...
# VLCSr_pos                     6.2.1.7                                SLC27A2
# XANDp_pos                   1.1.1.204                                    XDH
# XAOx_pos                    1.1.1.204                                    XDH
# XYLUR_neg                    1.1.1.10                                   DCXR
# XYLUR_pos                    1.1.1.10                                   DCXR
#
#                                                                rxn_formula  \
# 2HBO_pos                 1.00 * 2-Hydroxybutyrate [c] + 1.00 * Nicotina...
# 34DHOXPEGOX_pos          1.00 * proton [c] + 1.00 * Nicotinamide adenin...
# 34DHPLACOX_NADP__neg     1.00 * Water [c] + 1.00 * Nicotinamide adenine...
# 34DHPLACOX_pos           1.00 * Water [c] + 1.00 * Nicotinamide adenine...
# 34DHXMANDACOX_NADP__neg  1.00 * Water [c] + 1.00 * Nicotinamide adenine...
# ...                                                                    ...
# VLCSr_pos                1.00 * ATP [r] + 1.00 * Coenzyme A [r] + 1.00 ...
# XANDp_pos                1.00 * Nicotinamide adenine dinucleotide [x] +...
# XAOx_pos                 1.00 * O2 [x] + 1.00 * Water [x] + 1.00 * Xant...
# XYLUR_neg                1.00 * proton [c] + 1.00 * Nicotinamide adenin...
# XYLUR_pos                1.00 * proton [c] + 1.00 * Nicotinamide adenin...
#
#                          rxn_confidence
# 2HBO_pos                            4.0
# 34DHOXPEGOX_pos                     4.0
# 34DHPLACOX_NADP__neg                4.0
# 34DHPLACOX_pos                      4.0
# 34DHXMANDACOX_NADP__neg             4.0
# ...                                 ...
# VLCSr_pos                           4.0
# XANDp_pos                           4.0
# XAOx_pos                            4.0
# XYLUR_neg                           4.0
# XYLUR_pos                           4.0
#
# [448 rows x 12 columns]

# %% [markdown]
# ## subsystem level

# %%
pvn_sub_all = pd.read_csv(hypergeom_dir + 'results_Th17p_v_n_compass_rxns_q.csv', index_col = 0)
nvp_sub_all = pd.read_csv(hypergeom_dir + 'results_Th17n_v_p_compass_rxns_q.csv', index_col = 0)
pvn_sub = pvn_sub_all[pvn_sub_all['q'] < 0.05]
nvp_sub = nvp_sub_all[nvp_sub_all['q'] < 0.05]
subsystem_terms = pd.read_csv(hypergeom_dir + 'subsystem_term_names.csv')['0']

# %%
sig_data[sig_data['cohens_d'] > 0]['subsystem'].value_counts()
# Out:
# Sphingolipid metabolism                              40
# Nucleotide interconversion                           39
# Blood group synthesis                                20
# Folate metabolism                                    20
# Pyrimidine catabolism                                18
# Tyrosine metabolism                                  18
# Valine, leucine, and isoleucine metabolism           16
# Cholesterol metabolism                               14
# Purine catabolism                                    12
# Bile acid synthesis                                  11
# Glycerophospholipid metabolism                       11
# Pentose phosphate pathway                            10
# Pyruvate metabolism                                   9
# Inositol phosphate metabolism                         9
# C5-branched dibasic acid metabolism                   8
# Vitamin A metabolism                                  8
# Aminosugar metabolism                                 8
# Arginine and Proline Metabolism                       8
# Glycine, serine, alanine and threonine metabolism     7
# Methionine and cysteine metabolism                    7
# Purine synthesis                                      7
# Glutathione metabolism                                6
# NAD metabolism                                        5
# Pyrimidine synthesis                                  5
# Triacylglycerol synthesis                             5
# Fatty acid oxidation                                  4
# Glutamate metabolism                                  4
# Alanine and aspartate metabolism                      4
# Keratan sulfate degradation                           3
# Glyoxylate and dicarboxylate metabolism               3
# Steroid metabolism                                    3
# beta-Alanine metabolism                               3
# Propanoate metabolism                                 3
# Glycolysis/gluconeogenesis                            2
# Eicosanoid metabolism                                 2
# Urea cycle                                            2
# Lysine metabolism                                     2
# Fructose and mannose metabolism                       2
# Histidine metabolism                                  1
# Fatty acid synthesis                                  1
# Starch and sucrose metabolism                         1
# Tryptophan metabolism                                 1
# Name: subsystem, dtype: int64

# %%
pvn_sub
# Out:
# Empty DataFrame
# Columns: [term, p, padj, q]
# Index: []

# %%
nvp_sub
# Out:
#                            term         p  padj    q
# 2         Aminosugar metabolism  0.805022   NaN  0.0
# 4             Lysine metabolism  0.788394   NaN  0.0
# 6   Selenoamino acid metabolism  0.624860   NaN  0.0
# 12         Transport, lysosomal  0.750773   NaN  0.0
# 13               NAD metabolism  0.037964   NaN  0.0
# 14        Propanoate metabolism  0.624860   NaN  0.0
# 15               Heme synthesis  0.387407   NaN  0.0

# %%
# 1: get proportion of shared items that are significant
def get_overlap(compass, hypergeom, col1 = 'term', col2 = 'subsystem'):
    intersection = len(set(hypergeom[col1]) & set(compass[col2]))
    return intersection/len(set(compass[col2])), intersection/len(set(hypergeom[col1]))

# %%
# 2: get correlation between cohen's d & q value for all
def get_correlation(compass, hypergeom, how = 'pearson', col1 = 'term', col2 = 'subsystem'):
    compass_df = compass.groupby(col2).mean()
    hypergeom_df = hypergeom.copy()
    hypergeom_df.index = hypergeom_df[col1]
    shared_subsystems = [i for i in compass_df.index if i in hypergeom_df.index]
    hypergeom_df = hypergeom_df.loc[shared_subsystems]
    compass_df = compass_df.loc[shared_subsystems]
    if len(shared_subsystems) > 1:
        if how == 'pearson':
            res = stats.pearsonr(hypergeom_df['q'], abs(compass_df['cohens_d']))[0]
        elif how == 'spearman':
            res = stats.spearmanr(hypergeom_df['q'], abs(compass_df['cohens_d']))[0]
        else:
            raise(f'how should be pearson or spearman')
        return res
    else:
        return np.nan

# %%
# 3: hypergeometric for overlap between significant results
def get_hypergeom_overlap(compass, hypergeom, all_terms = subsystem_terms, col1 = 'term', col2 = 'subsystem'):
    compass_d = set(compass[compass['adjusted_pval']< 0.05][col2])
    compass_d = compass_d & set(all_terms)
    M = len(all_terms)
    n = len(hypergeom) # number of met genes
    N = len(compass_d)
    x = len(compass_d & set(hypergeom[col1]))
    pct_overlap = x/(N+n)
    hypergeom_model = stats.hypergeom(M=M, n=n, N=N)
    p_val = hypergeom_model.sf(x-1)
    return p_val

# %% [markdown]
# **for enrichment in pathogenic**

# %%
print(f"compass length: {len(sig_data[sig_data['cohens_d'] > 0]['subsystem'].unique())} hypergeom_length: {len(pvn_sub)}")
print(f"n overlap: {len(set(sig_data[sig_data['cohens_d'] > 0]['subsystem']) & set(pvn_sub['term']))}")
pvn_sub_overlap = get_overlap(sig_data[sig_data['cohens_d'] > 0], pvn_sub)
print(f"compass overlap: {pvn_sub_overlap[0]} hypergeom_length: {pvn_sub_overlap[1]}")
# Out:
# compass length: 42 hypergeom_length: 15
# n overlap: 9
# compass overlap: 0.21428571428571427 hypergeom_length: 0.6

# %%
print(f"correlation between compass' cohen's d and hypergeom's q values")
print(f"negative correlation is most similar")
print(f'for all values:')
print(f"pearson: {get_correlation(data[data['cohens_d'] > 0], pvn_sub_all[pvn_sub_all['q'].notna()])}")
print(f"spearman: {get_correlation(data[data['cohens_d'] > 0], pvn_sub_all[pvn_sub_all['q'].notna()], how = 'spearman')}")
print(f'\nfor significant values:')
print(f"pearson: {get_correlation(sig_data[sig_data['cohens_d'] > 0], pvn_sub)}")
print(f"spearman: {get_correlation(sig_data[sig_data['cohens_d'] > 0], pvn_sub, how = 'spearman')}")
# Out:
# correlation between compass' cohen's d and hypergeom's q values
# negative correlation is most similar
# for all values:
# pearson: nan
# spearman: nan
#
# for significant values:
# pearson: nan
# spearman: nan
# /Genomics/argo/users/azsun/.conda/envs/gene_scoring/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Genomics/argo/users/azsun/.conda/envs/gene_scoring/lib/python3.9/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /Genomics/argo/users/azsun/.conda/envs/gene_scoring/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Genomics/argo/users/azsun/.conda/envs/gene_scoring/lib/python3.9/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())

# %%
print(f"hypergeometric test: {get_hypergeom_overlap(sig_data[sig_data['cohens_d'] > 0], pvn_sub)}")
# Out:
# hypergeometric test: 0.012875820154438873

# %% [markdown]
# **for enrichment in non-pathogenic**

# %%
print(f"compass length: {len(sig_data[sig_data['cohens_d'] < 0]['subsystem'].unique())} hypergeom_length: {len(nvp_sub)}")
print(f"n overlap: {len(set(sig_data[sig_data['cohens_d'] < 0]['subsystem']) & set(nvp_sub['term']))}")
nvp_sub_overlap = get_overlap(sig_data[sig_data['cohens_d'] < 0], nvp_sub)
print(f"compass overlap: {nvp_sub_overlap[0]} hypergeom_length: {nvp_sub_overlap[1]}")
# Out:
# compass length: 13 hypergeom_length: 0
# n overlap: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [70], in <cell line: 3>()
#       1 print(f"compass length: {len(sig_data[sig_data['cohens_d'] < 0]['subsystem'].unique())} hypergeom_length: {len(nvp_sub)}")
#       2 print(f"n overlap: {len(set(sig_data[sig_data['cohens_d'] < 0]['subsystem']) & set(nvp_sub['term']))}")
# ----> 3 nvp_sub_overlap = get_overlap(sig_data[sig_data['cohens_d'] < 0], nvp_sub)
#       4 print(f"compass overlap: {nvp_sub_overlap[0]} hypergeom_length: {nvp_sub_overlap[1]}")
#
# Input In [64], in get_overlap(compass, hypergeom, col1, col2)
#       2 def get_overlap(compass, hypergeom, col1 = 'term', col2 = 'subsystem'):
#       3     intersection = len(set(hypergeom[col1]) & set(compass[col2]))
# ----> 4     return intersection/len(set(compass[col2])), intersection/len(set(hypergeom[col1]))
#
# ZeroDivisionError: division by zero

# %%
print(f"correlation between compass' cohen's d and hypergeom's q values")
print(f"negative correlation is most similar")
print(f'for all values:')
print(f"pearson: {get_correlation(data[data['cohens_d'] < 0], nvp_sub_all[nvp_sub_all['q'].notna()])}")
print(f"spearman: {get_correlation(data[data['cohens_d'] < 0], nvp_sub_all[nvp_sub_all['q'].notna()], how = 'spearman')}")
print(f'\nfor significant values:')
print(f"pearson: {get_correlation(sig_data[sig_data['cohens_d'] < 0], nvp_sub)}")
print(f"spearman: {get_correlation(sig_data[sig_data['cohens_d'] < 0], nvp_sub, how = 'spearman')}")
# Out:
# correlation between compass' cohen's d and hypergeom's q values
# negative correlation is most similar
# for all values:
# pearson: -0.9792311437440882
# spearman: -0.7071067811865475
#
# for significant values:
# pearson: nan
# spearman: nan

# %%
print(f"hypergeometric test: {get_hypergeom_overlap(sig_data[sig_data['cohens_d'] < 0], nvp_sub)}")
# Out:
# hypergeometric test: 1.0

# %% [markdown]
# **both results**

# %%
print('pathogenic enriched terms')
print('---raw proportion overlap---')
print(f"compass length: {len(sig_data[sig_data['cohens_d'] > 0]['subsystem'].unique())} hypergeom_length: {len(pvn_sub)}")
print(f"n overlap: {len(set(sig_data[sig_data['cohens_d'] > 0]['subsystem']) & set(pvn_sub['term']))}")
pvn_sub_overlap = get_overlap(sig_data[sig_data['cohens_d'] > 0], pvn_sub)
print(f"compass overlap: {pvn_sub_overlap[0]} hypergeom_overlap: {pvn_sub_overlap[1]}")
print('\n---correlation---')
print(f"correlation between compass' cohen's d (mean of each subsystem) and hypergeom's q values")
print(f"negative correlation is most similar")
print(f'for all values:')
print(f"pearson: {get_correlation(data[data['cohens_d'] > 0], pvn_sub_all[pvn_sub_all['q'].notna()])}")
print(f"spearman: {get_correlation(data[data['cohens_d'] > 0], pvn_sub_all[pvn_sub_all['q'].notna()], how = 'spearman')}")
print(f'\nfor significant values:')
print(f"pearson: {get_correlation(sig_data[sig_data['cohens_d'] > 0], pvn_sub)}")
print(f"spearman: {get_correlation(sig_data[sig_data['cohens_d'] > 0], pvn_sub, how = 'spearman')}")
print('\n---hypergeometric test for overlap---')
print(f"hypergeometric test: {get_hypergeom_overlap(sig_data[sig_data['cohens_d'] > 0], pvn_sub)}")
# Out:
# pathogenic enriched terms
# ---raw proportion overlap---
# compass length: 42 hypergeom_length: 15
# n overlap: 9
# compass overlap: 0.21428571428571427 hypergeom_overlap: 0.6
#
# ---correlation---
# correlation between compass' cohen's d (mean of each subsystem) and hypergeom's q values
# negative correlation is most similar
# for all values:
# pearson: nan
# spearman: nan
#
# for significant values:
# pearson: nan
# spearman: nan
#
# ---hypergeometric test for overlap---
# hypergeometric test: 0.012875820154438873
# /Genomics/argo/users/azsun/.conda/envs/gene_scoring/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Genomics/argo/users/azsun/.conda/envs/gene_scoring/lib/python3.9/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /Genomics/argo/users/azsun/.conda/envs/gene_scoring/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Genomics/argo/users/azsun/.conda/envs/gene_scoring/lib/python3.9/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())

# %%
print('nonpathogenic enriched terms')
print('---raw proportion overlap---')
print(f"compass length: {len(sig_data[sig_data['cohens_d'] < 0]['subsystem'].unique())} hypergeom_length: {len(nvp_sub)}")
print(f"n overlap: {len(set(sig_data[sig_data['cohens_d'] < 0]['subsystem']) & set(nvp_sub['term']))}")
nvp_sub_overlap = get_overlap(sig_data[sig_data['cohens_d'] < 0], nvp_sub)
print(f"compass overlap: {nvp_sub_overlap[0]} hypergeom_overlap: {nvp_sub_overlap[1]}")
print('\n---correlation---')
print(f"correlation between compass' cohen's d and hypergeom's q values")
print(f"negative correlation is most similar")
print(f'for all values:')
print(f"pearson: {get_correlation(data[data['cohens_d'] < 0], nvp_sub_all[nvp_sub_all['q'].notna()])}")
print(f"spearman: {get_correlation(data[data['cohens_d'] < 0], nvp_sub_all[nvp_sub_all['q'].notna()], how = 'spearman')}")
print(f'\nfor significant values:')
print(f"pearson: {get_correlation(sig_data[sig_data['cohens_d'] < 0], nvp_sub)}")
print(f"spearman: {get_correlation(sig_data[sig_data['cohens_d'] < 0], nvp_sub, how = 'spearman')}")
print('\n---hypergeometric test for overlap---')
print(f"hypergeometric test: {get_hypergeom_overlap(sig_data[sig_data['cohens_d'] < 0], nvp_sub)}")
# Out:
# nonpathogenic enriched terms
# ---raw proportion overlap---
# compass length: 13 hypergeom_length: 0
# n overlap: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [76], in <cell line: 5>()
#       3 print(f"compass length: {len(sig_data[sig_data['cohens_d'] < 0]['subsystem'].unique())} hypergeom_length: {len(nvp_sub)}")
#       4 print(f"n overlap: {len(set(sig_data[sig_data['cohens_d'] < 0]['subsystem']) & set(nvp_sub['term']))}")
# ----> 5 nvp_sub_overlap = get_overlap(sig_data[sig_data['cohens_d'] < 0], nvp_sub)
#       6 print(f"compass overlap: {nvp_sub_overlap[0]} hypergeom_overlap: {nvp_sub_overlap[1]}")
#       7 print('\n---correlation---')
#
# Input In [64], in get_overlap(compass, hypergeom, col1, col2)
#       2 def get_overlap(compass, hypergeom, col1 = 'term', col2 = 'subsystem'):
#       3     intersection = len(set(hypergeom[col1]) & set(compass[col2]))
# ----> 4     return intersection/len(set(compass[col2])), intersection/len(set(hypergeom[col1]))
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## reaction level

# %%
pvn_rxn_all = pd.read_csv(hypergeom_dir + 'results_Th17p_v_n_compass_rxns_q_reaction_scoring.csv', index_col = 0)
nvp_rxn_all = pd.read_csv(hypergeom_dir + 'results_Th17n_v_p_compass_rxns_q_reaction_scoring.csv', index_col = 0)
pvn_rxn = pvn_rxn_all[pvn_rxn_all['q'] < 0.05]
nvp_rxn = nvp_rxn_all[nvp_rxn_all['q'] < 0.05]

# %%
sig_pvn = sig_data[sig_data['cohens_d'] > 0]
sig_nvp = sig_data[sig_data['cohens_d'] < 0]

# %%
# first pass: replicate subsystem functions

# %%
print('pathogenic enriched terms - reactions')
print('---raw proportion overlap---')
print(f"compass length: {len(sig_pvn[sig_pvn['cohens_d'] > 0]['metadata_r_id'].unique())} hypergeom_length: {len(pvn_rxn)}")
print(f"n overlap: {len(set(sig_pvn[sig_pvn['cohens_d'] > 0]['metadata_r_id']) & set(pvn_rxn['term']))}")
pvn_rxn_overlap = get_overlap(sig_pvn[sig_pvn['cohens_d'] > 0], pvn_rxn, col2 = 'metadata_r_id')
print(f"compass overlap: {pvn_rxn_overlap[0]} hypergeom_length: {pvn_rxn_overlap[1]}")

print('\n---correlation---')
print(f"correlation between compass' cohen's d and hypergeom's q values")
print(f"negative correlation is most similar")
print(f'for all values:')
print(f"pearson: {get_correlation(data[data['cohens_d'] > 0], pvn_rxn_all[pvn_rxn_all['q'].notna()], col2 = 'metadata_r_id')}")
print(f"spearman: {get_correlation(data[data['cohens_d'] > 0], pvn_rxn_all[pvn_rxn_all['q'].notna()], col2 = 'metadata_r_id', how = 'spearman')}")
print(f'\nfor significant values:')
print(f"pearson: {get_correlation(sig_pvn, pvn_rxn, col2 = 'metadata_r_id')}")
print(f"spearman: {get_correlation(sig_pvn, pvn_rxn, col2 = 'metadata_r_id', how = 'spearman')}")

print('\n---hypergeometric test for overlap---')
print(f"hypergeometric test: {get_hypergeom_overlap(sig_data[sig_data['cohens_d'] > 0], pvn_rxn, all_terms = list(set(data['metadata_r_id'])), col2 = 'metadata_r_id')}")
# Out:
# pathogenic enriched terms - reactions
# ---raw proportion overlap---
# compass length: 533 hypergeom_length: 430
# n overlap: 238
# compass overlap: 0.44652908067542213 hypergeom_length: 0.5534883720930233
#
# ---correlation---
# correlation between compass' cohen's d and hypergeom's q values
# negative correlation is most similar
# for all values:
# pearson: -0.4681307659676278
# spearman: -0.48108655431259906
#
# for significant values:
# pearson: -0.4681307659676278
# spearman: -0.48108655431259906
#
# ---hypergeometric test for overlap---
# hypergeometric test: 1.0

# %%
print('nonpathogenic enriched terms - reactions')
print('---raw proportion overlap---')
print(f"compass length: {len(sig_nvp[sig_nvp['cohens_d'] < 0]['metadata_r_id'].unique())} hypergeom_length: {len(nvp_rxn)}")
print(f"n overlap: {len(set(sig_nvp[sig_nvp['cohens_d'] < 0]['metadata_r_id']) & set(nvp_rxn['term']))}")
nvp_rxn_overlap = get_overlap(sig_nvp[sig_nvp['cohens_d'] < 0], nvp_rxn, col2 = 'metadata_r_id')
print(f"compass overlap: {nvp_rxn_overlap[0]} hypergeom_length: {nvp_rxn_overlap[1]}")

print('\n---correlation---')
print(f"correlation between compass' cohen's d and hypergeom's q values")
print(f"negative correlation is most similar")
print(f'for all values:')
print(f"pearson: {get_correlation(data[data['cohens_d'] < 0], nvp_rxn_all[nvp_rxn_all['q'].notna()], col2 = 'metadata_r_id')}")
print(f"spearman: {get_correlation(data[data['cohens_d'] < 0], nvp_rxn_all[nvp_rxn_all['q'].notna()], col2 = 'metadata_r_id', how = 'spearman')}")
print(f'\nfor significant values:')
print(f"pearson: {get_correlation(sig_nvp, nvp_rxn, col2 = 'metadata_r_id')}")
print(f"spearman: {get_correlation(sig_nvp, nvp_rxn, col2 = 'metadata_r_id', how = 'spearman')}")

print('\n---hypergeometric test for overlap---')
print(f"hypergeometric test: {get_hypergeom_overlap(sig_data[sig_data['cohens_d'] < 0], nvp_rxn, all_terms = list(set(data['metadata_r_id'])), col2 = 'metadata_r_id')}")
# Out:
# nonpathogenic enriched terms - reactions
# ---raw proportion overlap---
# compass length: 11 hypergeom_length: 423
# n overlap: 8
# compass overlap: 0.7272727272727273 hypergeom_length: 0.018912529550827423
#
# ---correlation---
# correlation between compass' cohen's d and hypergeom's q values
# negative correlation is most similar
# for all values:
# pearson: -0.4009249279586441
# spearman: -0.25043516133890464
#
# for significant values:
# pearson: -0.4009249279586441
# spearman: -0.25043516133890464
#
# ---hypergeometric test for overlap---
# hypergeometric test: 0.7877330248990326

# %%
color
# Out:
# 34DHOXPEGOX_pos        r
# 3DSPHR_pos             r
# 3SALATAi_pos           r
# 3SALATAim_pos          r
# 41R1H2MAE12BOOX_pos    r
#                       ..
# VALTA_pos              r
# VALTAm_neg             r
# VLCSp_pos              r
# XYLUR_neg              r
# XYLUR_pos              r
# Name: cohens_d, Length: 617, dtype: object

# %%
color = data['metadata_r_id'].map(lambda x: 'r' if x in pvn_rxn['term'] else 'b')

# %%
# only significant
data = W[~W['subsystem'].isin(["Miscellaneous", "Unassigned"])]
data = data[~data['subsystem'].map(lambda x: "Transport" in x or "Exchange" in x or x == "Other")]
items, counts = np.unique(data['subsystem'], return_counts=True)
items = [items[i] for i in range(len(items)) if counts[i] > 5] #filter(n() > 5) %>%
data = data[data['subsystem'].isin(items)]
data = data[data['adjusted_pval'] < 0.05]
plt.figure(figsize=(12,12))
axs = plt.gca()
#Sorts the reactions for plotting
d = data[data['adjusted_pval'] < 0.05].groupby('subsystem')['cohens_d'].median().abs()
axs.scatter(d[d.argsort], d[d.argsort].index, alpha=0)
#color = data['cohens_d'].map(lambda x: 'r' if x >= 0 else 'b')
alpha = data['adjusted_pval'].map(lambda x: 1.0 if x < 0.1 else 0.25)
axs.scatter(data['cohens_d'], data['subsystem'], c=color, alpha=alpha)
axs.set_xlabel("Cohen's d")
axs.vlines(x=0, ymin=-2, ymax=50, linestyles='--')

# %%
import matplotlib.pyplot as plt
import matplotlib
def plot_differential_scores(data, title, c):
    plt.figure(figsize=(10,10))
    axs = plt.gca()
    axs.scatter(data['cohens_d'], -np.log10(data['adjusted_pval']), c=c)
    axs.set_xlabel("Cohen's d", fontsize=16)
    axs.set_ylabel("-log10 (Wilcoxon-adjusted p)", fontsize=16)
    #Everything after this should be tweaked depending on your application
    axs.set_xlim(-6.2, 6.2)
    axs.axvline(0, dashes=(3,3), c='black')
    axs.axhline(1, dashes=(3,3), c='black')
    axs.set_title(title, fontdict={'fontsize':20})
    axs.annotate('', xy=(0.5, -0.08), xycoords='axes fraction', xytext=(0, -0.08),
            arrowprops=dict(arrowstyle="<-", color='#348C73', linewidth=4))
    axs.annotate('Th17p_V', xy=(0.75, -0.12), xycoords='axes fraction', fontsize=16)
    axs.annotate('', xy=(0.5, -0.08), xycoords='axes fraction', xytext=(1, -0.08),
            arrowprops=dict(arrowstyle="<-", color='#E92E87', linewidth=4))
    axs.annotate('Th17n_V', xy=(0.25, -0.12), xycoords='axes fraction', fontsize=16)
    for r in data.index:
        if r in labeled_reactions:
            x = data.loc[r, 'cohens_d']
            y = -np.log10(data.loc[r, 'adjusted_pval'])
            offset = (20, 0)
            if x < 0:
                offset = (-100, -40)
            axs.annotate(labeled_reactions[r], (x,y), xytext = offset,
                         textcoords='offset pixels', arrowprops={'arrowstyle':"-"})

# %%
filtered_data = pd.concat([W[W['subsystem'] == "Nucleotide interconversion"],
                           W[W['subsystem'] == "Fatty acid oxidation"],
                           W[W['subsystem'] == "Keratan sulfate synthesis"],
                           W[W['subsystem'] == "Keratan sulfate degradation"],
                          ])

# %%
for item in filtered_data['subsystem'].value_counts().keys():
    data = W[W['subsystem'] == item]
    plot_differential_scores(data, title=item, c="#695D73")

# %%
keys = ["Inositol phosphate metabolism", "Heme synthesis", "Cholesterol metabolism", 
        "Aminosugar metabolism", "Keratan sulfate synthesis", "N-glycan degradation"]
for item in keys:
    data = W[W['subsystem'] == item]
    plot_differential_scores(data, title=item, c="#695D73")
