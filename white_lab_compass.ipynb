# %% [markdown]
# To install the required python packages, you can uncomment the lines below. Versions of matplotlib older than 3.4 may not support arrays of alphas for scatter plots, which will break generating figure 2E. Otherwise it should work fine.

# %%
#!pip install pandas
#!pip install "matplotlib>=3.4"
#!pip install numpy

# %%
import pandas as pd
import numpy as np
from scipy.stats import wilcoxon, mannwhitneyu, ranksums
from statsmodels.stats.multitest import multipletests
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as hcluster
from scipy.spatial.distance import squareform

# %% [markdown]
# This notebook, gives a small demo of analyzing the results of the compass algorithm and replicates figures 2E and 2C from the paper.

# %% [markdown]
# The file "extdata/Th17/reactions.tsv" is the outputs of a compass run and "extdata/Th17/cell_metadata.csv" is cell
# metadata, in this case it is only used to know the condition of the Th17 cells (pathogenic vs. non-pathogenic)

# %%
dir = '/Genomics/pritykinlab/zzhao/metabolic_analysis/metabolic_analysis/compass_white'
reactions = pd.read_csv(f"{dir}/reactions.tsv", sep="\t", index_col = 0)

# %%
cell_metadata = pd.read_csv("/Genomics/pritykinlab/zzhao/bulkRNA/datafiles/metadata_cleaned.csv", index_col = 0)
cell_metadata['tissue'] = cell_metadata['filename'].str.replace('--', '-').str.replace('GN-P', 'GNP').apply(lambda x: x.split('-')[-1])
cell_metadata = cell_metadata.set_index('filename')

# %%
# mutant = M; wild-type = W
# mutant = M; wild-type = W
M_cells = cell_metadata.index[(cell_metadata['Mouse Genotype Code'] == 'M') & (cell_metadata['Gender'] == 'Male') & (cell_metadata['tissue'] == 'Liver') & (cell_metadata['Weeks Post Deletion'] == '6')]
W_cells = cell_metadata.index[(cell_metadata['Mouse Genotype Code'] == 'W') & (cell_metadata['Gender'] == 'Male') & (cell_metadata['tissue'] == 'Liver') & (cell_metadata['Weeks Post Deletion'] == '6')]

# M_cells = cell_metadata.index[(cell_metadata['Mouse Genotype Code'] == 'W') & (cell_metadata['Gender'] == 'Female') & (cell_metadata['tissue'] == 'Liver')]
# W_cells = cell_metadata.index[(cell_metadata['Mouse Genotype Code'] == 'W') & (cell_metadata['Gender'] == 'Male') & (cell_metadata['tissue'] == 'Liver')]
# M_cells = cell_metadata.index[(cell_metadata['Mouse Genotype Code'] == 'M') & (cell_metadata['Gender'] == 'Female') & (cell_metadata['tissue'] == 'Liver')]
# W_cells = cell_metadata.index[(cell_metadata['Mouse Genotype Code'] == 'W') & (cell_metadata['Gender'] == 'Female') & (cell_metadata['tissue'] == 'Liver')]

# %% [markdown]
# The reaction metadata for RECON2 is stored here. We'll be using the confidence scores and the subsystem groupings to filter out reactions and group them for analysis.

# %%
reaction_metadata = pd.read_csv("extdata/RECON2/reaction_metadata.csv", index_col = 0)

# %% [markdown]
# Here is one example of a row for the reaction metadata:

# %%
M_cells
# Out:
# Index(['6DarkATG7KO1936-108-Liver', '6DarkATG7KO1950-113-Liver',
#        '6LightATG7KO1956-133-Liver'],
#       dtype='object', name='filename')

# %%
W_cells
# Out:
# Index(['6DarkATG7WT2013-90-Liver', '6DarkATG7WT2015-93-Liver',
#        '6LightATG7WT1975-86-Liver', '6LightATG7WT1977-144-Liver'],
#       dtype='object', name='filename')

# %%
def cohens_d(x, y):
    pooled_std = np.sqrt(((len(x)-1) * np.var(x, ddof=1) 
                          + (len(y)-1) * np.var(y, ddof=1)) / 
                             (len(x) + len(y) - 2))
    return (np.mean(x) - np.mean(y)) / pooled_std
    

def wilcoxon_test(consistencies_matrix, group_A_cells, group_B_cells):
    """
        Performs an unpaired wilcoxon test (or mann-whitney U test) for each reaction between group_A and group_B
    """
    #per reaction/meta-reaction, conduct wilcoxon test between group_A and group_B
    group_A = consistencies_matrix.loc[:,group_A_cells]
    group_B = consistencies_matrix.loc[:,group_B_cells]
    results = pd.DataFrame(index = consistencies_matrix.index, columns = ['wilcox_stat', 'wilcox_pval', 'cohens_d'], dtype='float64')
    for rxn in consistencies_matrix.index:
        A, B = group_A.loc[rxn].to_numpy().ravel(), group_B.loc[rxn].to_numpy().ravel()
        stat, pval = mannwhitneyu(A, B, alternative='two-sided')
        c_d = cohens_d(A, B)
        results.loc[rxn, ['wilcox_stat', 'wilcox_pval', 'cohens_d']] = stat, pval, c_d
    results['adjusted_pval'] = np.array(multipletests(results['wilcox_pval'], method='fdr_bh')[1], dtype='float64')
    return results

# %%
def get_reaction_consistencies(compass_reaction_scores, min_range=1e-3):
    df = -np.log(compass_reaction_scores + 1)
    df = df[df.max(axis=1) - df.min(axis=1) >= min_range]
    df = df - df.min().min()
    return df

# %% [markdown]
# The numbers in the reactions tsv correspond to penalties for each reaction per cell, so we take the negative log to get scores that are higher the more active the reaction is predicted to be.This also drops reactions that are close to constant and therefore not informative for the comparison.

# %%
reaction_consistencies = get_reaction_consistencies(reactions)

# %% [markdown]
# We use the unpaired Wilcoxon rank-sum test (equivlanet to the Mann–Whitney U test) to analyze which reactions are predicted to be more active in pathogenic Th17p cells compared to the non-pathogenic Th17n cells. Positive values indicate higher potential activity in Th17p.

# %%
reaction_consistencies
# Out:
#                          12DarkATG7KOfemale1911-21-GNP  \
# 10FTHF5GLUtl_pos                              3.379102
# 10FTHF5GLUtm_pos                              3.154236
# 10FTHF6GLUtl_pos                              3.267017
# 10FTHF6GLUtm_pos                              3.140140
# 10FTHF7GLUtl_pos                              3.224334
# ...                                                ...
# sink_decdicoa(c)_neg                          2.007450
# sink_octdececoa(c)_neg                        1.778795
# sink_pre_prot(r)_neg                          7.514938
# sink_tetdec2coa(c)_neg                        2.007450
# sink_tetdece1coa(c)_neg                       2.007450
#
#                          12DarkATG7KOfemale1911-22-iWAT  \
# 10FTHF5GLUtl_pos                               3.403520
# 10FTHF5GLUtm_pos                               3.176589
# 10FTHF6GLUtl_pos                               3.295814
# 10FTHF6GLUtm_pos                               3.167134
# 10FTHF7GLUtl_pos                               3.257145
# ...                                                 ...
# sink_decdicoa(c)_neg                           2.040350
# sink_octdececoa(c)_neg                         1.821326
# sink_pre_prot(r)_neg                           7.560039
# sink_tetdec2coa(c)_neg                         2.040350
# sink_tetdece1coa(c)_neg                        2.040350
#
#                          12DarkATG7KOfemale1911-23-BAT  \
# 10FTHF5GLUtl_pos                              3.376083
# 10FTHF5GLUtm_pos                              3.134862
# 10FTHF6GLUtl_pos                              3.252824
# 10FTHF6GLUtm_pos                              3.118743
# 10FTHF7GLUtl_pos                              3.205691
# ...                                                ...
# sink_decdicoa(c)_neg                          2.027324
# sink_octdececoa(c)_neg                        1.816431
# sink_pre_prot(r)_neg                          7.513552
# sink_tetdec2coa(c)_neg                        2.027324
# sink_tetdece1coa(c)_neg                       2.027324
#
#                          12DarkATG7KOfemale1911-24-Liver  \
# 10FTHF5GLUtl_pos                                3.394776
# 10FTHF5GLUtm_pos                                3.244040
# 10FTHF6GLUtl_pos                                3.312579
# 10FTHF6GLUtm_pos                                3.235880
# 10FTHF7GLUtl_pos                                3.274856
# ...                                                  ...
# sink_decdicoa(c)_neg                            2.052876
# sink_octdececoa(c)_neg                          1.843250
# sink_pre_prot(r)_neg                            7.522777
# sink_tetdec2coa(c)_neg                          2.052876
# sink_tetdece1coa(c)_neg                         2.052876
#
#                          12DarkATG7KOfemale1911-25-Cerebellum  \
# 10FTHF5GLUtl_pos                                     3.391313
# 10FTHF5GLUtm_pos                                     3.156955
# 10FTHF6GLUtl_pos                                     3.281204
# 10FTHF6GLUtm_pos                                     3.146178
# 10FTHF7GLUtl_pos                                     3.241458
# ...                                                       ...
# sink_decdicoa(c)_neg                                 2.039537
# sink_octdececoa(c)_neg                               1.799891
# sink_pre_prot(r)_neg                                 7.566481
# sink_tetdec2coa(c)_neg                               2.039537
# sink_tetdece1coa(c)_neg                              2.039537
#
#                          12DarkATG7KOfemale1914-26-GNP  \
# 10FTHF5GLUtl_pos                              3.376164
# 10FTHF5GLUtm_pos                              3.164309
# 10FTHF6GLUtl_pos                              3.267654
# 10FTHF6GLUtm_pos                              3.150333
# 10FTHF7GLUtl_pos                              3.224872
# ...                                                ...
# sink_decdicoa(c)_neg                          2.004451
# sink_octdececoa(c)_neg                        1.777295
# sink_pre_prot(r)_neg                          7.516248
# sink_tetdec2coa(c)_neg                        2.004451
# sink_tetdece1coa(c)_neg                       2.004451
#
#                          12DarkATG7KOfemale1914-27-Liver  \
# 10FTHF5GLUtl_pos                                3.397298
# 10FTHF5GLUtm_pos                                3.244649
# 10FTHF6GLUtl_pos                                3.315894
# 10FTHF6GLUtm_pos                                3.236922
# 10FTHF7GLUtl_pos                                3.278691
# ...                                                  ...
# sink_decdicoa(c)_neg                            2.050983
# sink_octdececoa(c)_neg                          1.839228
# sink_pre_prot(r)_neg                            7.529374
# sink_tetdec2coa(c)_neg                          2.050983
# sink_tetdece1coa(c)_neg                         2.050983
#
#                          12DarkATG7KOfemale1914-28-BAT  \
# 10FTHF5GLUtl_pos                              3.373264
# 10FTHF5GLUtm_pos                              3.128894
# 10FTHF6GLUtl_pos                              3.248509
# 10FTHF6GLUtm_pos                              3.111404
# 10FTHF7GLUtl_pos                              3.200579
# ...                                                ...
# sink_decdicoa(c)_neg                          2.022578
# sink_octdececoa(c)_neg                        1.811043
# sink_pre_prot(r)_neg                          7.510868
# sink_tetdec2coa(c)_neg                        2.022578
# sink_tetdece1coa(c)_neg                       2.022578
#
#                          12DarkATG7KOfemale1914-29-Cerebellum  \
# 10FTHF5GLUtl_pos                                     3.393182
# 10FTHF5GLUtm_pos                                     3.154075
# 10FTHF6GLUtl_pos                                     3.281665
# 10FTHF6GLUtm_pos                                     3.141795
# 10FTHF7GLUtl_pos                                     3.241882
# ...                                                       ...
# sink_decdicoa(c)_neg                                 2.039834
# sink_octdececoa(c)_neg                               1.800139
# sink_pre_prot(r)_neg                                 7.569434
# sink_tetdec2coa(c)_neg                               2.039834
# sink_tetdece1coa(c)_neg                              2.039834
#
#                          12DarkATG7KOfemale1914-30-iWAT  ...  \
# 10FTHF5GLUtl_pos                               3.402877  ...
# 10FTHF5GLUtm_pos                               3.171719  ...
# 10FTHF6GLUtl_pos                               3.293768  ...
# 10FTHF6GLUtm_pos                               3.161723  ...
# 10FTHF7GLUtl_pos                               3.254605  ...
# ...                                                 ...  ...
# sink_decdicoa(c)_neg                           2.032945  ...
# sink_octdececoa(c)_neg                         1.810962  ...
# sink_pre_prot(r)_neg                           7.560545  ...
# sink_tetdec2coa(c)_neg                         2.032945  ...
# sink_tetdece1coa(c)_neg                        2.032945  ...
#
#                          6LightATG7WT1977-143-BAT  6LightATG7WT1977-144-Liver  \
# 10FTHF5GLUtl_pos                         3.380923                    3.390370
# 10FTHF5GLUtm_pos                         3.135561                    3.240868
# 10FTHF6GLUtl_pos                         3.260056                    3.306713
# 10FTHF6GLUtm_pos                         3.117880                    3.232371
# 10FTHF7GLUtl_pos                         3.213652                    3.268169
# ...                                           ...                         ...
# sink_decdicoa(c)_neg                     2.026281                    2.038968
# sink_octdececoa(c)_neg                   1.816859                    1.832365
# sink_pre_prot(r)_neg                     7.514068                    7.519382
# sink_tetdec2coa(c)_neg                   2.026281                    2.038968
# sink_tetdece1coa(c)_neg                  2.026281                    2.038968
#
#                          6LightATG7WT2040-125-Cerebellum  \
# 10FTHF5GLUtl_pos                                3.394326
# 10FTHF5GLUtm_pos                                3.153868
# 10FTHF6GLUtl_pos                                3.282006
# 10FTHF6GLUtm_pos                                3.141945
# 10FTHF7GLUtl_pos                                3.242185
# ...                                                  ...
# sink_decdicoa(c)_neg                            2.043489
# sink_octdececoa(c)_neg                          1.799631
# sink_pre_prot(r)_neg                            7.575424
# sink_tetdec2coa(c)_neg                          2.043489
# sink_tetdece1coa(c)_neg                         2.043489
#
#                          6LightATG7WT2040-126-BAT  6LightATG7WT2040-127-GNP  \
# 10FTHF5GLUtl_pos                         3.381237                  3.372116
# 10FTHF5GLUtm_pos                         3.137587                  3.153704
# 10FTHF6GLUtl_pos                         3.259618                  3.260843
# 10FTHF6GLUtm_pos                         3.122377                  3.138921
# 10FTHF7GLUtl_pos                         3.212550                  3.217166
# ...                                           ...                       ...
# sink_decdicoa(c)_neg                     2.029756                  2.003157
# sink_octdececoa(c)_neg                   1.816990                  1.774096
# sink_pre_prot(r)_neg                     7.514377                  7.508902
# sink_tetdec2coa(c)_neg                   2.029756                  2.003157
# sink_tetdece1coa(c)_neg                  2.029756                  2.003157
#
#                          6LightATG7WT2040-128-Liver  \
# 10FTHF5GLUtl_pos                           3.396657
# 10FTHF5GLUtm_pos                           3.242839
# 10FTHF6GLUtl_pos                           3.313779
# 10FTHF6GLUtm_pos                           3.234819
# 10FTHF7GLUtl_pos                           3.276350
# ...                                             ...
# sink_decdicoa(c)_neg                       2.048415
# sink_octdececoa(c)_neg                     1.839924
# sink_pre_prot(r)_neg                       7.523378
# sink_tetdec2coa(c)_neg                     2.048415
# sink_tetdece1coa(c)_neg                    2.048415
#
#                          6LightATG7WT2041-77-Liver  6LightATG7WT2041-78-BAT  \
# 10FTHF5GLUtl_pos                          3.393634                 3.383547
# 10FTHF5GLUtm_pos                          3.243242                 3.139367
# 10FTHF6GLUtl_pos                          3.311468                 3.263019
# 10FTHF6GLUtm_pos                          3.235003                 3.126086
# 10FTHF7GLUtl_pos                          3.273703                 3.217016
# ...                                            ...                      ...
# sink_decdicoa(c)_neg                      2.045266                 2.025817
# sink_octdececoa(c)_neg                    1.837642                 1.805043
# sink_pre_prot(r)_neg                      7.515323                 7.509125
# sink_tetdec2coa(c)_neg                    2.045266                 2.025817
# sink_tetdece1coa(c)_neg                   2.045266                 2.025817
#
#                          6LightATG7WT2041-79-Cerebellum  \
# 10FTHF5GLUtl_pos                               3.394090
# 10FTHF5GLUtm_pos                               3.157722
# 10FTHF6GLUtl_pos                               3.282577
# 10FTHF6GLUtm_pos                               3.147346
# 10FTHF7GLUtl_pos                               3.243015
# ...                                                 ...
# sink_decdicoa(c)_neg                           2.039693
# sink_octdececoa(c)_neg                         1.798912
# sink_pre_prot(r)_neg                           7.567414
# sink_tetdec2coa(c)_neg                         2.039693
# sink_tetdece1coa(c)_neg                        2.039693
#
#                          6LightATG7WT2041-80-GNP
# 10FTHF5GLUtl_pos                        3.367362
# 10FTHF5GLUtm_pos                        3.134589
# 10FTHF6GLUtl_pos                        3.249670
# 10FTHF6GLUtm_pos                        3.119868
# 10FTHF7GLUtl_pos                        3.205123
# ...                                          ...
# sink_decdicoa(c)_neg                    2.000908
# sink_octdececoa(c)_neg                  1.770206
# sink_pre_prot(r)_neg                    7.503539
# sink_tetdec2coa(c)_neg                  2.000908
# sink_tetdece1coa(c)_neg                 2.000908
#
# [6564 rows x 162 columns]

# %%
wilcox_results = wilcoxon_test(reaction_consistencies, W_cells, M_cells)
wilcox_results['metadata_r_id'] = ""
for r in wilcox_results.index:
    if r in reaction_metadata.index:
        wilcox_results.loc[r, 'metadata_r_id'] = r
    elif r[:-4] in reaction_metadata.index:
        wilcox_results.loc[r, 'metadata_r_id'] = r[:-4]
    else:
        print("Should not occur")
# Out:
# /tmp/ipykernel_219530/1804728428.py:5: RuntimeWarning: invalid value encountered in double_scalars
#   return (np.mean(x) - np.mean(y)) / pooled_std
# /tmp/ipykernel_219530/1804728428.py:5: RuntimeWarning: invalid value encountered in double_scalars
#   return (np.mean(x) - np.mean(y)) / pooled_std
# /tmp/ipykernel_219530/1804728428.py:5: RuntimeWarning: invalid value encountered in double_scalars
#   return (np.mean(x) - np.mean(y)) / pooled_std
# /tmp/ipykernel_219530/1804728428.py:5: RuntimeWarning: invalid value encountered in double_scalars
#   return (np.mean(x) - np.mean(y)) / pooled_std
# /tmp/ipykernel_219530/1804728428.py:5: RuntimeWarning: invalid value encountered in double_scalars
#   return (np.mean(x) - np.mean(y)) / pooled_std
# /tmp/ipykernel_219530/1804728428.py:5: RuntimeWarning: invalid value encountered in double_scalars
#   return (np.mean(x) - np.mean(y)) / pooled_std
# /tmp/ipykernel_219530/1804728428.py:5: RuntimeWarning: invalid value encountered in double_scalars
#   return (np.mean(x) - np.mean(y)) / pooled_std
# /tmp/ipykernel_219530/1804728428.py:5: RuntimeWarning: invalid value encountered in double_scalars
#   return (np.mean(x) - np.mean(y)) / pooled_std
# /tmp/ipykernel_219530/1804728428.py:5: RuntimeWarning: invalid value encountered in double_scalars
#   return (np.mean(x) - np.mean(y)) / pooled_std
# /tmp/ipykernel_219530/1804728428.py:5: RuntimeWarning: invalid value encountered in double_scalars
#   return (np.mean(x) - np.mean(y)) / pooled_std

# %% [markdown]
# Next we join the metadata to the reactions in a new dataframe W, so that we can filter out non-core reactions. More specifically, we remove reactions with confidence other than 0 or 4 (4 = most confident; 0 = unassigned confidence) and filter out reactions in the citric acid cycle subsystem which are outside of the mitochondria.

# %%
W = wilcox_results.merge(reaction_metadata, how='left', 
                         left_on='metadata_r_id', right_index=True, validate='m:1')
W = W[W['confidence'].isin([1, 2, 3, 4])]
W = W[~W['EC_number'].isna()]
W.loc[(W['formula'].map(lambda x: '[m]' not in x)) & (W['subsystem'] == "Citric acid cycle"), 'subsystem'] = 'Other'

# %% [markdown]
# Here is one example of a row of the reuslting dataframe for a reaction:

# %% [markdown]
# The "_neg" or "_pos" suffixes indicate one direction of a bidirectional reaction. The "_pos" direction indicates positive flux through the reaction. For this example reaction it indicates water, oxygen, and putrescine are being consumed by this reaction to produce ammonium, hyrodgen peroxide, and 4-Aminobutanal.

# %%
reaction_metadata.loc['r0281']['formula']
# Out:
# '1.00 * Water [e] + 1.00 * O2 [e] + 1.00 * Putrescine [e] --> 1.00 * Ammonium [e] + 1.00 * Hydrogen peroxide [e] + 1.00 * 4-Aminobutanal [e]\nAOC1'

# %%
data = W[~W['subsystem'].isin(["Miscellaneous", "Unassigned"])]
data = data[~data['subsystem'].map(lambda x: "Transport" in x or "Exchange" in x or x == "Other")]
items, counts = np.unique(data['subsystem'], return_counts=True)
items = [items[i] for i in range(len(items)) if counts[i] > 5] #filter(n() > 5) %>%
data = data[data['subsystem'].isin(items)]

# %%
data.sort_values(['wilcox_pval']).head(20)
# Out:
#                            wilcox_stat  wilcox_pval  cohens_d  adjusted_pval  \
# CYSGLTH_pos                        0.0     0.057143 -1.747134            1.0
# LTD4DP_pos                         0.0     0.057143 -3.092362            1.0
# PUNP7_neg                          0.0     0.057143 -2.174399            1.0
# ATPH2e_pos                         0.0     0.057143 -2.739122            1.0
# LTC4CP_pos                         0.0     0.057143 -3.092362            1.0
# LTC4CP_neg                         0.0     0.057143 -3.092362            1.0
# BAAT1x_pos                        12.0     0.057143  1.377544            1.0
# 3MOX4HOXPGALDOX_pos                0.0     0.057143 -2.574423            1.0
# PUNP3_pos                          0.0     0.057143 -2.174399            1.0
# BAAT4x_pos                        12.0     0.057143  1.377544            1.0
# CSNAT2x_neg                       12.0     0.057143  1.781405            1.0
# MMEm_neg                          12.0     0.057143  1.298246            1.0
# BTNDe_pos                         12.0     0.057143  2.175697            1.0
# OPAHir_pos                         0.0     0.057143 -2.708312            1.0
# ADKd_pos                           0.0     0.057143 -2.009319            1.0
# MMMm_pos                          12.0     0.057143  1.274309            1.0
# 3MOX4HOXPGALDOX_NADP__neg          0.0     0.057143 -2.574423            1.0
# LTD4DP_neg                         0.0     0.057143 -3.092362            1.0
# LNELDCCPT1_pos                    12.0     0.057143  1.410497            1.0
# FAOXC16080m_pos                   12.0     0.057143  1.268566            1.0
#
#                                    metadata_r_id  \
# CYSGLTH_pos                              CYSGLTH
# LTD4DP_pos                                LTD4DP
# PUNP7_neg                                  PUNP7
# ATPH2e_pos                                ATPH2e
# LTC4CP_pos                                LTC4CP
# LTC4CP_neg                                LTC4CP
# BAAT1x_pos                                BAAT1x
# 3MOX4HOXPGALDOX_pos              3MOX4HOXPGALDOX
# PUNP3_pos                                  PUNP3
# BAAT4x_pos                                BAAT4x
# CSNAT2x_neg                              CSNAT2x
# MMEm_neg                                    MMEm
# BTNDe_pos                                  BTNDe
# OPAHir_pos                                OPAHir
# ADKd_pos                                    ADKd
# MMMm_pos                                    MMMm
# 3MOX4HOXPGALDOX_NADP__neg  3MOX4HOXPGALDOX_NADP_
# LTD4DP_neg                                LTD4DP
# LNELDCCPT1_pos                        LNELDCCPT1
# FAOXC16080m_pos                      FAOXC16080m
#
#                                                                reaction_name  \
# CYSGLTH_pos                               Glutathione:cystine oxidoreductase
# LTD4DP_pos                                        Leukotriene D4 dipeptidase
# PUNP7_neg                       purine-nucleoside phosphorylase (Xanthosine)
# ATPH2e_pos                                            ATP diphosphohydrolase
# LTC4CP_pos                                   Leukotriene C4 carboxypeptidase
# LTC4CP_neg                                   Leukotriene C4 carboxypeptidase
# BAAT1x_pos                 bile acid Coenzyme A: amino acid N-acyltransfe...
# 3MOX4HOXPGALDOX_pos        3-Methoxy-4-hydroxyphenylglycolaldehyde:NAD+ o...
# PUNP3_pos                        purine-nucleoside phosphorylase (Guanosine)
# BAAT4x_pos                 bile acid Coenzyme A: amino acid N-acyltransfe...
# CSNAT2x_neg                carnitine dimethyl nonanoyl transferase, revsi...
# MMEm_neg                                methylmalonyl-CoA epimerase/racemase
# BTNDe_pos                                biotinidase (biotin), extracellular
# OPAHir_pos                 5-Oxoproline amidohydrolase (ATP-hydrolysing) ...
# ADKd_pos                                           adenylate kinase (d form)
# MMMm_pos                                            methylmalonyl-CoA mutase
# 3MOX4HOXPGALDOX_NADP__neg  3-Methoxy-4-hydroxyphenylglycolaldehyde:NADP+ ...
# LTD4DP_neg                                        Leukotriene D4 dipeptidase
# LNELDCCPT1_pos                              carnitine O-palmitoyltransferase
# FAOXC16080m_pos                      Beta oxidation of long chain fatty acid
#
#                                                                      formula  \
# CYSGLTH_pos                1.00 * L-cystine [c] + 2.00 * Reduced glutathi...
# LTD4DP_pos                 1.00 * Water [c] + 1.00 * Leukotriene D4 [c] -...
# PUNP7_neg                  1.00 * hydrogenphosphate [c] + 1.00 * xanthosi...
# ATPH2e_pos                 1.00 * Water [e] + 1.00 * ADP [e] --> 1.00 * p...
# LTC4CP_pos                 1.00 * Water [c] + 1.00 * leukotriene C4(2-) [...
# LTC4CP_neg                 1.00 * Water [c] + 1.00 * leukotriene C4(2-) [...
# BAAT1x_pos                 1.00 * Glycine [x] + 1.00 * choloyl-CoA(4-) [x...
# 3MOX4HOXPGALDOX_pos        1.00 * Water [c] + 1.00 * Nicotinamide adenine...
# PUNP3_pos                  1.00 * hydrogenphosphate [c] + 1.00 * Guanosin...
# BAAT4x_pos                 1.00 * Glycine [x] + 1.00 * chenodeoxycholoyl ...
# CSNAT2x_neg                1.00 * L-Carnitine [x] + 1.00 * 4,8 dimethylno...
# MMEm_neg                   1.00 * (R)-methylmalonyl-CoA(5-) [m] --> 1.00 ...
# BTNDe_pos                  1.00 * Water [e] + 1.00 * Biocytin [e] --> 1.0...
# OPAHir_pos                 2.00 * Water [c] + 1.00 * ATP [c] + 1.00 * 5-o...
# ADKd_pos                   1.00 * dAMP(2-) [c] + 1.00 * dATP [c] --> 2.00...
# MMMm_pos                   1.00 * (R)-methylmalonyl-CoA(5-) [m] --> 1.00 ...
# 3MOX4HOXPGALDOX_NADP__neg  1.00 * Water [c] + 1.00 * Nicotinamide adenine...
# LTD4DP_neg                 1.00 * Water [c] + 1.00 * Leukotriene D4 [c] -...
# LNELDCCPT1_pos             1.00 * L-Carnitine [c] + 1.00 * linoelaidyl co...
# FAOXC16080m_pos            4.00 * Water [m] + 4.00 * Coenzyme A [m] + 4.0...
#
#                                                          associated_genes  \
# CYSGLTH_pos                                                           NaN
# LTD4DP_pos                                                            NaN
# PUNP7_neg                                                            PNP2
# ATPH2e_pos                 ENTPD1; ENTPD2; ENTPD3; ENTPD5; ENTPD6; ENTPD8
# LTC4CP_pos                                                            NaN
# LTC4CP_neg                                                            NaN
# BAAT1x_pos                                                           BAAT
# 3MOX4HOXPGALDOX_pos                    ALDH1A3; ALDH3A1; ALDH3B1; ALDH3B3
# PUNP3_pos                                                            PNP2
# BAAT4x_pos                                                           BAAT
# CSNAT2x_neg                                                    CRAT; CROT
# MMEm_neg                                                             MCEE
# BTNDe_pos                                                             BTD
# OPAHir_pos                                                          OPLAH
# ADKd_pos                                                              AK5
# MMMm_pos                                                              MUT
# 3MOX4HOXPGALDOX_NADP__neg              ALDH1A3; ALDH3A1; ALDH3B1; ALDH3B3
# LTD4DP_neg                                                            NaN
# LNELDCCPT1_pos                                        CPT1A; CPT1B; CPT1C
# FAOXC16080m_pos                                              ACADM; ACADS
#
#                                                             subsystem  \
# CYSGLTH_pos                        Methionine and cysteine metabolism
# LTD4DP_pos                                      Eicosanoid metabolism
# PUNP7_neg                                  Nucleotide interconversion
# ATPH2e_pos                                 Nucleotide interconversion
# LTC4CP_pos                                      Eicosanoid metabolism
# LTC4CP_neg                                      Eicosanoid metabolism
# BAAT1x_pos                                        Bile acid synthesis
# 3MOX4HOXPGALDOX_pos                               Tyrosine metabolism
# PUNP3_pos                                           Purine catabolism
# BAAT4x_pos                                        Bile acid synthesis
# CSNAT2x_neg                                      Fatty acid oxidation
# MMEm_neg                   Valine, leucine, and isoleucine metabolism
# BTNDe_pos                                           Biotin metabolism
# OPAHir_pos                                     Glutathione metabolism
# ADKd_pos                                   Nucleotide interconversion
# MMMm_pos                   Valine, leucine, and isoleucine metabolism
# 3MOX4HOXPGALDOX_NADP__neg                         Tyrosine metabolism
# LTD4DP_neg                                      Eicosanoid metabolism
# LNELDCCPT1_pos                                   Fatty acid oxidation
# FAOXC16080m_pos                                  Fatty acid oxidation
#
#                           EC_number  confidence
# CYSGLTH_pos                 1.8.4.4         4.0
# LTD4DP_pos                  2.3.2.2         4.0
# PUNP7_neg                   3.4.2.1         4.0
# ATPH2e_pos                  3.6.1.5         4.0
# LTC4CP_pos                  2.3.2.2         2.0
# LTC4CP_neg                  2.3.2.2         2.0
# BAAT1x_pos                 2.3.1.65         4.0
# 3MOX4HOXPGALDOX_pos         1.2.1.5         2.0
# PUNP3_pos                   3.4.2.1         4.0
# BAAT4x_pos                 2.3.1.65         2.0
# CSNAT2x_neg                 2.3.1.7         4.0
# MMEm_neg                   5.1.99.1         4.0
# BTNDe_pos                  3.5.1.12         4.0
# OPAHir_pos                  3.5.2.9         4.0
# ADKd_pos                    2.7.4.3         4.0
# MMMm_pos                   5.4.99.2         4.0
# 3MOX4HOXPGALDOX_NADP__neg   1.2.1.5         2.0
# LTD4DP_neg                  2.3.2.2         4.0
# LNELDCCPT1_pos             2.3.1.21         4.0
# FAOXC16080m_pos            4.2.1.74         4.0

# %%
data['wilcox_pval'].hist()
# Out:
# <AxesSubplot:>

# %%
data['adjusted_pval'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,12))
axs = plt.gca()
#Sorts the reactions for plotting
d = data[data['adjusted_pval'] <=1].groupby('subsystem')['cohens_d'].median().abs()
axs.scatter(d[d.argsort], d[d.argsort].index, alpha=0)
color = data['cohens_d'].map(lambda x: 'r' if x >= 0 else 'b')
alpha = data['wilcox_pval'].map(lambda x: 1.0 if x < 0.1 else 0.1)
axs.scatter(data['cohens_d'], data['subsystem'], c=color, alpha=alpha)
axs.set_xlabel("Cohen's d")
# Out:
# Text(0.5, 0, "Cohen's d")
